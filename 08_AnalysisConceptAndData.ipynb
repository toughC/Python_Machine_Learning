# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print("aaaa", "bbbb")
print(end='\t')
print("aaaa", "bbbb", sep="/")
# Out:
# aaaa bbbb
# 	aaaa/bbbb

# %%
class ppdata():
    def pdata(a, b=1, c=1):
        s=0
        try:
            s=int(a)+int(b)+int(c)
        except:
            print('0~9사이 아라비아 숫자만 입력해')
        
        return s

print(ppdata.pdata(1, 3, 5))

aa=input("숫자입력:")
print(ppdata.pdata(aa))
# Out:
# 9
# 숫자입력:45
# 47

# %% [markdown]
# ### 데이터 사이언스 공부 url
# -  https://mindscale.kr/

# %% [markdown]
# ### 머신러닝/딥러닝?
# - 수학자들이 만들어 놓은 통계분석 공식을 프로그램화 한것
# - 인공지능의 한 분야로, 기계가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 연구분야
# - 컴퓨터가 경험을 통해 학습할 수 있도록 프로그래밍할 수 있다면, 세세하게 프로그래밍해야 하는 번거로움을 벗어날 수 있다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 기계가 일일이 코드로 명시하지 않은 동작을 데이터로부터 학습하여 실행할 수 있도록 하는 알고리즘을 개발하는 연구 분야
# - 머신러닝이란 풀고자 하는 문제의 정답과 데이터를 주고 기계를 학습시켜서 정답을 맞추게 하는 것<br><br>
# - 머신러닝의 대표적인 알고리즘에는 선형회귀, 의사결정나무, 랜덤포레스트, K-최근접 이웃, 클러스터링 등이 존재하며 이 외에도 수많은 알고리즘이 존재함

# %% [markdown]
# - 머신러닝 학습방법
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 지도학습: y값이 있어서 ,그 y값과 예측값의 차이를 최소화하는 식을 찾아내는 과정이 가능한 자료셋이 있는 분석(회기분석)
#     - 회기: y값이 무한대의 값중 1개의 값으로 예측
#     - 선형(x의 차수가 최대1인) 식, ->직선식, 선형대수학: 일차방정식의 행렬처리
# - 비지도: y값 없이 x데이터의 특징값등의 유사도로 분석(군집분석)

# %% [markdown]
# ### 분석이란?
# - 분석할 가치가 있는가?
# - 서울에서 부산까지 5시간 소요
#     - 가설: 새벽 출발/오전 출발/오후 출발/저녁출발 ===> 5시간 소요(귀무가설:H0) ==> 분석할 가치가 있는가?
#     - 결과: 새벽출발(4시간)/오전출발(5시간)/오후출발(4시간30)/저녁출발(6시간) ==> 5시간이 아니다(대립 가설)
#     - 분석되었다면 그 계수값이나, 분석공식은 타당한가(머신러닝 설명력)
#         * 선형회귀기본: OLS,  분류: 오차분류표(정밀도, 재현율등), XG부스트: 변수중요도
#     - 통계학적으로는: 귀무가설체택, or 귀무가설 버리고 대립가설을 체택할것인지를 수학적으로 풀어야함. : p-value라고함
#     - 요즘은 이러한 원론적인 통계는 버리고, 시각화로도 이러한 데이터 패턴을 알수 있음 학문이 대세 =>EDA
# <br><br>
# 패턴분석의 기초학문: 평균, 편차, 표준편차, 분산, 분포도(히스토그램, 정규분포여부)를 먼저 이해

# %% [markdown]
# ### 기초통계
# - 참조: https://mindscale.kr/course/basic-stat-python/
# - 도수분포표(frequency table): 데이터를 구간으로 나누어, 각 구간의 빈도를 나타낸 표
# - 히스토그램(histogram): 도수분포표를 그래프로 그린 것

# %%
blood = ['A', 'A', 'A', 'B', 'B', 'AB', 'O']

import numpy as np
print(np.unique(blood))
print(np.unique(blood, return_counts=True))
# Out:
# ['A' 'AB' 'B' 'O']
# (array(['A', 'AB', 'B', 'O'], dtype='<U2'), array([3, 1, 2, 1]))

# %%
import pandas as pd
pd.Series(blood).value_counts()
# Out:
# A     3
# B     2
# AB    1
# O     1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(blood)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 연속 변수: 데이터 범위(구간) 정의
x = [1, 1, 1, 2, 3, 5, 5, 7, 8, 9]

hist, edges = np.histogram(x, 5)

# 구간별 빈도수
print(hist)

# 구간 경계
print(edges)
# Out:
# [4 1 2 1 2]
# [1.  2.6 4.2 5.8 7.4 9. ]

# %%
sns.distplot(x, bins=4, kde=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x = [100, 100, 200, 400, 500]
y = [100, 100, 200, 400, 10000]

# 평균
print(np.mean(x))
print(np.mean(y))
# Out:
# 260.0
# 2160.0

# %%
# 중앙값: 자료를 크기 순으로 정렬했을 때 정 가운데에 있는 값
print(np.median(x))
print(np.median(y))
# Out:
# 200.0
# 200.0

# %%
# 분산: 평균에서 데이터가 벗어난 정도를 수치화한 값
# 각각의 데이터에서 평균값을 빼고, 그것을 제곱하여 평균을 구함

x = [1, 1, 2, 3, 3, 3, 4, 5, 5, 7]

평균=np.mean(x)
분산=np.var(x)
print(분산)
# Out:
# 3.2399999999999998

# %%
# 표준편자: 평균에서 데이터가 벗어난 정도를 수치화한 값(분산의 양의 제곱근)
print(np.sqrt(np.var(x)))
print(np.std(x))
# Out:
# 1.8
# 1.8

# %% [markdown]
# ##### 사분위간 범위
# - 사분위간 범위(IQR, InterQuartile Range)는 제3사분위수에서 제1사분위수 간의 범위
# - 사분위수란 전체 데이터를 작은 값부터 큰 값까지 순서대로 나열한 후 4등분 하였을 때, 각 지점에 해당하는 값
#
#     - 제1사분위수(Q1): 25% 지점
#     - 제2사분위수(Q2): 50% 지점 = 중간값
#     - 제3사분위수(Q3): 75%
# - 제1사분위수와 제3사분위수 사이의 구간에는 항상 전체 데이터의 50%가 포함 됨
#
# - 사분위는 임의로 정하는 기준이므로 필요에 따라 십분위 등으로 변경가능

# %%
print(np.quantile(x, .25))  # 1사분위
print(np.quantile(x, .5))   # 2사분위/중앙값
print(np.quantile(x, .75))  # 3사분위
print(np.quantile(x, .75) - np.quantile(x, .25))  # 사분위간 범위(Q3 - Q1):
# Out:
# 2.25
# 3.0
# 4.75
# 2.5

# %%
## 평균/분산/표준편차 계산하기
점수=[85, 82, 88, 86, 85, 93, 98, 40, 73, 83]
np.mean(점수)
np.var(점수)
np.sqrt(np.var(점수))
# Out:
# 15.126466871017831

# %% [markdown]
# #### 회기분석
# - 가장 넓은 의미로는 독립변수(x)로 종속변수(y)를 예측하는 것을 의미

# %% [markdown]
# ##### 선형회기분석
# - 회귀분석: 종속변수가 연속인 경우를 말하며 선형 회귀 분석을 의미한다.<br>
# (종속변수가 범주형인 경우 '분류'라고 한다.)
# - 독립변수가 일정하게 증가하면, 종속변수도 그에 비례해서 증가하거나 또는 감소하는 형태<br>
# (독립변수와 종속변수 사이에 직선적인 형태의 관계)
# - 밥을 한 그릇, 두 그릇, 세 그릇, .. 먹으면 체중이 100g, 200g, 300g으로 증가하기 때문에 이것을 그림으로 그려보면 직선이 그려진다

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6]
y = [100,150,200,250,300,350]

plt.scatter(x, y, color='r', s=20)
plt.plot(x, y)

plt.show()

# %% [markdown]
# ##### 회기계수
# - 독립변수의 변화가 종속변수를 얼마나 변화시키는가?
# - 선형 모형에서 x와 y의 관계를 수식: y=wx+b
# - w: 회귀계수(cofficient)
# - b: y-절편, 또는 절편(독립변수가 모두 0일때 종속변수 y의 값)

# %%
speed=[4,4,7,7,8,9,10,10,10,11,11,12,12,12,12,13,13,13,13,14,14,14,14,15,15,15,16,16,17,17,17,18,18,18,18,19,19,19,20,20,20,20,20,22,23,24,24,24,24,25]
dist=[2,10,4,22,16,10,18,26,34,17,28,14,20,24,28,26,34,34,46,26,36,60,80,20,26,54,32,40,32,40,50,42,56,76,84,36,46,68,32,48,52,56,64,66,54,70,92,93,120,85]

# %%
import seaborn as sns

sns.regplot(np.array(speed).reshape(-1, 1), dist, lowess=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df=pd.DataFrame()
df['speed'] =speed
df['dist'] =dist
df.head()
# Out:
#    speed  dist
# 0      4     2
# 1      4    10
# 2      7     4
# 3      7    22
# 4      8    16

# %%
fig, (ax1, ax2)=plt.subplots(1, 2)

sns.boxplot('speed', data=df, ax=ax1, orient='v')
ax1.set_title('speed')

sns.boxplot('dist', data=df, ax=ax2, orient='v')
ax2.set_title('sist')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
# ...
