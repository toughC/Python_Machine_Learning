# %% [markdown]
# ### 1. 웹 크롤링(crawling) 이해
# - Web상에 존재하는 Contents를 수집하는 작업 (프로그래밍으로 자동화 가능)
#     - HTML 페이지를 가져와서, HTML/CSS등을 파싱(구문 해석하는 것, parsing)하고, 필요한 데이터만 추출하는 기법
#     - Open API(Rest API)를 제공하는 서비스에 Open API를 호출해서, 받은 데이터 중 필요한 데이터만 추출하는 기법
#     - Selenium등 브라우저를 프로그래밍으로 조작해서, 필요한 데이터만 추출하는 기법

# %% [markdown]
# #### 2. BeautifulSoup 라이브러리
# - HTML의 태그를 파싱해서 필요한 데이터만 추출하는 함수를 제공하는 라이브러리
# - 참조: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# - 설치: pip install bs4

# %%
import requests # HTML 페이지 요청하기 위해 사용하는 라이브러리
from bs4 import BeautifulSoup as bs
url='https://kin.naver.com/'

res = requests.get(url) # 데이터를 요청할 때 사용함 <-> post로 요청할 경우도 있음, 파라미터 차이가 있음.
print(res.status_code) # 200이 나오면 정상
print(res.content)
# Out:
# 200
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n<meta name="referrer" contents="always">\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="description" content="\xec\xa7\x80\xec\x8b\x9d\xeb\x82\x98\xeb\x88\x94\xea\xb3\xbc \xea\xb8\xb0\xeb\xb6\x80\xeb\xa1\x9c \xed\x95\xa8\xea\xbb\x98 \xec\x84\xb1\xec\x9e\xa5\xed\x95\x98\xeb\x8a\x94 \xec\xa7\x80\xec\x8b\x9diN\xec\x9d\x84 \xeb\xa7\x8c\xeb\x82\x98\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94."/>\n<meta name="viewport" content="width=1024">\n\n<meta name="msapplication-config" content="none" />\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/common.css" />\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/components.css" />\n\n\n\t\n\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/other.css">\n\t\n\n\n\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/main.css" />\n\t\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/c3p.datalab.theme.css" />\n\t\n\n\n\n\n<script>\n\t\n\tvar pcDomain = "kin.naver.com";\n\tvar pcDomainWithProtocol = "https://kin.naver.com";\n\tvar pcKinServiceProtocol = "https";\n\n\tvar mobileDomain = "m.kin.naver.com";\n\tvar mobileDomainWithProtocol = "https://m.kin.naver.com";\n\tvar mobileKinServiceProtocol = "https";\n\n\tvar uploadDomain = "upload.kin.naver.com";\n\tvar uploadDomainWithProtocol = "https://upload.kin.naver.com";\n\tvar uploadKinServiceProtocol = "https";\n</script>\n\n\n\t<script type="text/javascript" src="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/js/min/kin.js"></script>\n\n\n\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n\n\n\t<meta name="robots" content="index,nofollow" />\n\n\n\n\n\n\n\n\n\t\n\n\n<meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xec\xa7\x80\xec\x8b\x9diN"/>\n\n\n\t<meta property="og:url" content="https://kin.naver.com/index.naver"/>\n\n\n\n\t<meta property="og:image" content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png"/>\n\n<meta property="og:description" content="\xec\xa7\x80\xec\x8b\x9d\xeb\x82\x98\xeb\x88\x94\xea\xb3\xbc \xea\xb8\xb0\xeb\xb6\x80\xeb\xa1\x9c \xed\x95\xa8\xea\xbb\x98 \xec\x84\xb1\xec\x9e\xa5\xed\x95\x98\xeb\x8a\x94 \xec\xa7\x80\xec\x8b\x9diN\xec\x9d\x84 \xeb\xa7\x8c\xeb\x82\x98\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94."/>\n<meta property="og:article:author" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xec\xa7\x80\xec\x8b\x9diN"/>\n<meta property="og:article:author:url" content="https://kin.naver.com"/>\n\n<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?v=2.4">\n<title>\n\t\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xec\xa7\x80\xec\x8b\x9diN\n</title>\n\n<script type="text/javascript">\n\nif ( typeof window.nhn  == "undefined" ) window.nhn = {};\nif ( typeof window.naver  == "undefined" ) window.naver = {};\nnhn.isLogin = false;\nnhn.isJunior = ("N"=="Y");\nnhn.isKinUser = false;\nnhn.isPortableDevice = false;\nnhn.jsDir = \'https://ssl.pstatic.net/static.kin/static/pc/20221207140750/js/min\';\n\nvar g_ssc = ("kin.home" == "") ? "kin.temp" : "kin.home";\nvar ccsrv="cc.naver.com";\n\n\nvar kinRos = {\n\tbIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,\n\tbIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true\n\n};\n\n\n\n\n\nvar standardReportPopupUrl = "https://srp2.naver.com/report";\n</script>\n\n</head>\n\n\n<body>\n\t\n\t<div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">\n\t\ ...

# %%
# 바이너리 원문을 보여준다.
res.content[:500]
# Out:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n<meta name="referrer" contents="always">\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="description" content="\xec\xa7\x80\xec\x8b\x9d\xeb\x82\x98\xeb\x88\x94\xea\xb3\xbc \xea\xb8\xb0\xeb\xb6\x80\xeb\xa1\x9c \xed\x95\xa8\xea\xbb\x98 \xec\x84\xb1\xec\x9e\xa5\xed\x95\x98\xeb\x8a\x94 \xec\xa7\x80\xec\x8b\x9diN\xec\x9d\x84 \xeb\xa7\x8c\xeb\x82\x98\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94."/>\n<meta name="viewport" content="width=1024">\n\n<meta name="msapplication-config" content="none" />\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static'

# %%
# UTF-8로 인코딩된 문자열을 출력해준다.
res.text[:500]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\n\n\n\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n<meta name="referrer" contents="always">\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="description" content="지식나눔과 기부로 함께 성장하는 지식iN을 만나보세요."/>\n<meta name="viewport" content="width=1024">\n\n<meta name="msapplication-config" content="none" />\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/common.css" />\n<l'

# %%
# 참고) 만약, 응답 데이터가 JSON 포멧이라면, json() 함수를 사용합니다.
# res.json()

# %%
# BeautifulSoup(HTML 데이터, 파싱방법)
soup = bs(res.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta contents="always" name="referrer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="지식나눔과 기부로 함께 성장하는 지식iN을 만나보세요." name="description">
# <meta content="width=1024" name="viewport"/>
# <meta content="none" name="msapplication-config">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/components.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/other.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/main.css" rel="stylesheet" type="text/css">
# <link href="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/css/min/c3p.datalab.theme.css" rel="stylesheet" type="text/css"/>
# <script>
#
# 	var pcDomain = "kin.naver.com";
# 	var pcDomainWithProtocol = "https://kin.naver.com";
# 	var pcKinServiceProtocol = "https";
#
# 	var mobileDomain = "m.kin.naver.com";
# 	var mobileDomainWithProtocol = "https://m.kin.naver.com";
# 	var mobileKinServiceProtocol = "https";
#
# 	var uploadDomain = "upload.kin.naver.com";
# 	var uploadDomainWithProtocol = "https://upload.kin.naver.com";
# 	var uploadKinServiceProtocol = "https";
# </script>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/js/min/kin.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="index,nofollow" name="robots">
# <meta content="네이버 지식iN" property="og:title">
# <meta content="https://kin.naver.com/index.naver" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static/kin/common/kin_thumbnail_new_w1000.png" property="og:image"/>
# <meta content="지식나눔과 기부로 함께 성장하는 지식iN을 만나보세요." property="og:description"/>
# <meta content="네이버 지식iN" property="og:article:author"/>
# <meta content="https://kin.naver.com" property="og:article:author:url"/>
# <link href="/favicon.ico?v=2.4" rel="shortcut icon" type="image/x-icon"/>
# <title>
# 	네이버 지식iN
# </title>
# <script type="text/javascript">
#
# if ( typeof window.nhn  == "undefined" ) window.nhn = {};
# if ( typeof window.naver  == "undefined" ) window.naver = {};
# nhn.isLogin = false;
# nhn.isJunior = ("N"=="Y");
# nhn.isKinUser = false;
# nhn.isPortableDevice = false;
# nhn.jsDir = 'https://ssl.pstatic.net/static.kin/static/pc/20221207140750/js/min';
#
# var g_ssc = ("kin.home" == "") ? "kin.temp" : "kin.home";
# var ccsrv="cc.naver.com";
#
#
# var kinRos = {
# 	bIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,
# 	bIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true
#
# };
#
#
#
#
#
# var standardReportPopupUrl = "https://srp2.naver.com/report";
# </script>
# </meta></meta></link></meta></meta></head>
# <body>
# <div id="loadingIndicator" style="display:none;width:100%;height:100%;position:fixed;top:0px;left:0px;background-color:transparent;z-index:10000;">
# <img alt="데이터 요청 응답 대기중" height="21" src="https://ssl.pstatic.net/static/kin/m/ico_lod2.gif" style="position:absolute;top:49%;left:49%;" width="21"/>
# </div>
# <div class="wrap wrap_home" id="wrap">
# <div class="skip_nav header_gnb_inner">
# <a class="skip" href="#gnb" onclick="nhn.Kin.Utility.skipNavigation('au_lnb_home');return false;">메인 메뉴 바로가기</a>
# <a class="skip" href="#contentsOfMain" onclick="nhn.Kin.Utility.skipNavigation('contentsOfMain');return false;">본문 바로가기</a>
# </div>
# <div class="header_wrap">
# <div aria-labelledby="ieUpdateBannerTitle" class="popup popup--header_notice" id="ieUpdateBanner" role="dialog" style="display: none;">
# <h1 class="blind" id="ieUpdateBannerTitle" tabindex="0">권장 브라우저 업데이트 안내</h1>
# <div class="popup__content">
# <div class="popup__title">
# <p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>
# </div>
# <div class="popup__maintext">
# <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>
# <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.
# 	$Fn(function() {
# 		var oAgent = jindo.$Agent().navigator();
# 		if (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {
# 			if (typeof naver.kin.SimpleBanner !== "undefined") {
# 				var oIeUpdateBanner = new naver.kin.SimpleBanner({
# 					sBannerId: "ieUpdateBannerArea"
# 				});
# 			}
# 		}
# 	}, this).attach(document, 'domready');
# </script>
# <div class="header_gnb">
# <div class="header_gnb_inner">
# <div class="header_gnb__cell">
# <h1 class="header_logo">
# <a class="logo_naver" href="http://www.naver.com" onclick="nhn.Kin.Utility.nClicks('STA.naverlogo', '', '', event);" title="나의 경쟁력, 네이버"><span class="logo_kin sp_common">NAVER</span></a>
# </h1>
# <div class="header_search">
# <h2 class="logo_wrap">
# <a class="sp_gnb icon_logo_kin" href="/" onclick="nhn.Kin.Utility.nClicks('STA.kin', '', '', event);">지식iN</a>
# </h2>
# <h3 class="blind">검색영역</h3>
# <form action="/search/list.naver" id="topSearch" method="get" name="topSearch" onsubmit="return checkQuery();">
# <fieldset>
# <legend>지식인 검색</legend>
# <div class="search_area">
# <input accesskey="s" aria-autocomplete="list" aria-controls="atcmpList" aria-expanded="false" aria-haspopup="listbox" autocomplete="off" class="search_input" id="nx_query" maxlength="255" name="query" onclick="nhn.Kin.Utility.nClicks('STA.search', '', '', event);return false;" role="combobox" title="검색어 입력" type="text" value=""/>
# <a class="search_auto" href="#">
# <span class="sp_gnb icon_arrow" id="triangleBtn">자동완성 열기</span>
# </a>
# <div>
# <iframe class="auto_complete_box" frameborder="0" height="193px" id="autoFrame" marginheight="0" marginwidth="0" scrolling="no" title="검색어 자동완성" width="290"></iframe>
# </div>
# <a class="search_btn" href="#" onclick="return checkQuery();"><span class="sp_gnb icon_search">지식iN 검색</span></a>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="header_gnb__cell">
# <div class="gnb_wrap">
# <div class="gnb_eXpertLogo">
# <a aria-controls="bannerExpert" aria-expanded="true" aria-haspopup="true" class="link" href="https://expert.naver.com" id="bannerLink" target="_blank">
# <span class="logo"><span class="blind">eXpert</span></span>
# </a>
# </div>
# <div class="gnb_chat _chatButtonArea">
# <button aria-controls="chatMenu" aria-expanded="false" aria-haspopup="true" aria-pressed="false" class="button_chat" id="chatButton" type="button">
# <span class="blind">상담 목록</span>
# <span class="icon_chat"></span>
# <i class="icon_new" style="display: none"><span class="blind">NEW</span></i>
# </button>
# <div aria-hidden="true" class="chat_popup" id="chatMenu" role="menu">
# <a class="link_chat" href="/expert/center/counseling/list" role="menuitem" target="_blank">
# 								판매한 상품
# 								<i class="_counselorNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# <a class="link_chat" href="/counseling/purchases" role="menuitem" target="_blank">
# 								구매한 상품
# 								<i class="_counseleeNewIcon icon_new" style="display: none"><span class="blind">NEW</span></i>
# </a>
# </div>
# </div>
# <div class="gnb_common_area">
# <div id="gnb">
# <script type="text/javascript">
#
# 								var gnb_service = "kin";
#
# 								var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 								var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 								var gnb_template = "gnb_utf8";
#
# 								var gnb_item_hide_option = 0;
#
#
#
#
# 							</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?2023011713" type="text/javascript"></script>
# </div>
# </div>
# </div>
# <div class="header__rolling rolling-notice">
# <i class="icon_speaker"><span class="blind">실시간 공지사항</span></i>
# <ul class="rolling-notice__list _rolling_banner" id="listNotice">
# <li class="rolling-notice__item _rollingItem" data-start-time="2021-10-26 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://expert.naver.com/expert/introduction?tab=guide#join" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">2023년 엑스퍼트 전문가 되자!</span>
# </a>
# </li>
# <li class="rolling-notice__item _rollingItem" data-start-time="2022-08-31 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://expert.naver.com/expert/introduction?tab=guide#join" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">지존도 이제 엑스퍼트</span>
# </a>
# </li>
# <li class="rolling-notice__item _rollingItem" data-start-time="2022-12-06 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://m.expert.naver.com/" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# 											전문가가 필요할 때! 엑스퍼트.
# 									</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- nav -->
# <div class="nav" role="navigation">
# <div class="nav_inner">
# <h3 class="blind">메인 메뉴</h3>
# <ul class="nav_list" id="au_lnb" role="menubar">
# <li class="menu" role="presentation">
# <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
# </li>
# <li class="menu" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
# <ul class="nav_sub_list _lnbSubMenu" role="menu">
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">컴퓨터통신</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
# </ul>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
# </li>
# <li class="menu" role="presentation">
# <span class="lnb_bar">|</span>
# <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
# </li>
# </ul>
# <a class="nav__button_question _clickcode:LNB.q" href="#" onclick="nhn.Kin.checkRosAndGoUrl(event, '/qna/question.naver', '');" role="button"><span class="btn_inner"><i class="sp_gnb icon_pencil"></i>질문하기</span></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	$Fn(function() {
# 		new naver.kin.LNB({
# 			'questionType' : ''
# 		});
# 	}).attach(window, 'load');
#
# 	var GNB_BRIGHTNESS_VALUE = {
# 		DARK_ICON : 0,
# 		DARK_ICON_AND_TRANSPARENCY : 1,
# 		BRIGHT_ICON_AND_TRANSPARENCY : 2,
# 		BRIGHT_ICON : 3
# 	};
#
# 	var GNB_ITEM_HIDE_OPTION_BIT_VALUE = {
# 		DEFAULT : 0,
# 		HIDE_LOGIN_BTN : 1,
# 		HIDE_USER_LAYER : 2,
# 		HIDE_NAVER_ME_AREA : 4,
# 		HIDE_MAIL_ALARM_AREA : 8,
# 		HIDE_PROFILE_IMAGE : 16,
# 		SHOW_BENEFIT_FOR_STAFF_MEMBER : 32
# 	};
#
#
# 	var smartSearch = "";
#
# 	var gnb_service = "kin";
#
# 	var gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");
#
# 	var gnb_login = encodeURIComponent(location.href || 'https://kin.naver.com');
#
# 	var gnb_template = "gnb_utf8";
#
# 	var gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;
#
#
#
#
#
# 	$Fn(function() {
#
# 		getGNB();
#
# 		var bIsGnbClicked = false;
#
#
# 		$Fn(function (we) {
# 			if (!bIsGnbClicked) {
# 				gnbAllLayerClose();
# 			}
#
# 			bIsGnbClicked = false;
# 		}, this).attach(document.body, 'click');
#
# 		$Fn(function(we) {
# 			bIsGnbClicked = true;
# 		}, this).attach($('gnb'), 'click');
#
#
# 		try {
# 			$('autoFrame').src = '/static/reatcmp.html?v=4.1';
# 		} catch(e) {
# 		}
#
# 		smartSearch = new nhn.AjaxSuggestUS('nx_query', 'autoFrame', {
# 			url : 'https://ac.search.naver.com/nx/ac',
# 			cookieName : 'NaverSuggestUse',
# 			listbox : '_resultBox',
# 			sFromName : 'topSearch',
# 			triangleBtn : 'triangleBtn',
# 			sListMaxLength : 55,
# 			listMaxCount : 15,
# 			request_type : 'jsonp',
# 			request_data : {
# 				q : '{query}',
# 				st : '100',
# 				r_format : 'json',
# 				t_koreng : '1',
# 				q_enc : 'UTF-8',
# 				r_enc : 'UTF-8',
# 				r_unicode : '0',
# 				r_escape : '1',
# 				frm : 'kin'
# 			},
# 			sTriangleUpOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_up.gif',
# 			sTriangleUpOff : 'https://ssl.pstatic.net/sstatic/search/mypocket/v3/btn_atcmp_off_op2.gif',
# 			sTriangleDownOn : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down.gif',
# 			sTriangleDownOff : 'https://ssl.pstatic.net/static/common/snb/090513/bu_arrow_down3.gif'
# 		}).attach({
# 			actSubmit : function() {
# 				try {
# 					top.selectAction(this._elForm);
# 				} catch(e) {
# 					try {
# 						selectAction(this._elForm);
# 					} catch(e) {
# 					}
# 				}
#
# 				this._elForm.submit();
# 			}
# 		});
#
# 		var expertEntryBanner = $$.getSingle("div.gnb_eXpertLogo div.banner");
# 		if (!!expertEntryBanner) {
# 			var cookie = new $Cookie();
#
# 			$Fn(function () {
# 				$Element(expertEntryBanner).hide();
#
# 				var newDisabledUntil = new Date().getTime() + (3 * 1000 * 24 * 60 * 60);
# 				cookie.set("kin_expert_entry_banner_disabled_until", newDisabledUntil, 5);
# 			}).attach($$.getSingle("div.gnb_eXpertLogo div.banner button.buttonCancel"), 'click');
#
# 			var disabledUntilTimestamp = new Number(cookie.get("kin_expert_entry_banner_disabled_until"));
# 			if (!isNaN(disabledUntilTimestamp)) {
# 				if (new Date().getTime() > disabledUntilTimestamp) {
# 					cookie.remove("kin_expert_entry_banner_disabled_until");
# 					$Element(expertEntryBanner).show();
# 				}
# 			} else {
# 				$Element(expertEntryBanner).show();
# 			}
# 		}
#
#
# 		if (typeof nhn.Kin.ChatMenu !== "undefined") {
# 			window.oChatMenu = new nhn.Kin.ChatMenu();
# 		}
# 	}).attach(window, 'load');
# </script>
# <div class="container-fluid" id="container" role="main">
# <div class="container-fluid-content">
# <div class="container-fluid-content-inner _containerFluidContentInner">
# <div class="section_spot">
# <div class="best_qna_wrap">
# <h4 class="blind">베스트 질문/답변</h4>
# <div class="best expert">
# <a class="best_link" href="https://expert.naver.com" target="_blank">
# <div aria-hidden="true" class="best_background">
# <div class="best_background_image" style="background-image:url(https://ssl.pstatic.net/static/kin/section/expert/pc/home_panel_expert2.png)"></div>
# <img alt="" src="https://ssl.pstatic.net/static/kin/section/expert/pc/home_panel_expert2.png"/>
# </div>
# <div class="best_title">
# <div class="subtitleBox"><h2 class="subtitle"><span class="blind">NEW</span></h2></div>
# <p class="description">전문가 상담이<br/>필요할 땐,<br/>지식iN 엑스퍼트</p>
# </div>
# </a>
# </div>
# <div class="best hall">
# <a class="best_link" href="/qna/detail.naver?d1id=11&amp;dirId=1111&amp;docId=339471195" onclick="nhn.Kin.Utility.nClicks('con.sanc', '', '', event);">
# <div class="best_title">
# <h2 class="subtitle"><span class="blind">지식iN 성지</span></h2>
# <p class="description">죄송한데 저 위로 좀 해주세요ㅠㅠㅠㅠㅠㅠ</p>
# </div>
# </a>
# </div>
# <div class="best today">
# <a class="best_link" href="/qna/detail.naver?d1id=8&amp;dirId=814&amp;docId=437174212" onclick="nhn.Kin.Utility.nClicks('con.today', '', '', event);">
# <div class="best_title">
# <h2 class="subtitle"><span class="blind">오늘의 질문</span></h2>
# <p class="description">내가 싫어하는 냄새는?!</p>
# </div>
# </a>
# </div>
# <div class="best aha">
# <a class="best_link" href="/qna/detail.naver?d1id=11&amp;dirId=11080301&amp;docId=434134259" onclick="nhn.Kin.Utility.nClicks('con.aha', '', '', event);">
# <div class="best_title">
# <h2 class="subtitle"><span class="blind">아하! 그렇구나</span></h2>
# <p class="description">미국 영국 발음 차이가 생긴 이유</p>
# </div>
# </a>
# </div>
# </div>
# <div class="banner_promot" id="rightTopBanner">
# <ul class="banner_list">
# <li class="_banner_1">
# <a class="_nclicks:sbn.thum" href="https://blog.naver.com/naver_expert/222949770202" target="_blank">
# <img alt="엑스퍼트 가입 조건 완화" height="220" src="https://ssl.pstatic.net/static/kin/09renewal/promotion/main/rb_6_main_20221209184031.png?ver=20221209064032" width="280"/>
# </a>
# </li>
# <li class="_banner_2" style="display:none">
# <a class="_nclicks:sbn.thum" href="https://blog.naver.com/kin_friend/222985535008" target="_blank">
# <img alt="2023년 첫미션 지식인토끼를 잡아라 채택답변 달성하고 토끼배지3종과 보너스 내공을 받으세요" height="220" src="https://ssl.pstatic.net/static/kin/09renewal/promotion/main/rb_4_main_20230116094945.png?ver=20230116094946" width="280"/>
# </a>
# </li>
# <li class="_banner_3" style="display:none">
# <a class="_nclicks:sbn.thum" href="https://blog.naver.com/naver_expert/222942941066" target="_blank">
# <img alt="엑스퍼트 디자인 전문가" height="220" src="https://ssl.pstatic.net/static/kin/09renewal/promotion/main/rb_1_main_20221215182335.png?ver=20221215062335" width="280"/>
# </a>
# </li>
# </ul>
# <div class="paging _bannerPaging">
# <a class="_clickcode:sbn.btn on _bannerPage _banner_1" href="#">1</a>
# <a class="_clickcode:sbn.btn _bannerPage _banner_2" href="#">2</a>
# <a class="_clickcode:sbn.btn _bannerPage _banner_3" href="#">3</a>
# </div>
# </div>
# <script type="text/javascript">
# 		$Fn(function() {
# 			var elRightTopBanner = $("rightTopBanner");
# 			var elBannerList = $$("li", elRightTopBanner);
# 			var elBannerPaging = $$.getSingle("._bannerPaging", elRightTopBanner);
# 			var elBannerPagingList = $$("a._bannerPage", elBannerPaging);
# 			$Fn(function(oEvent) {
# 				if(oEvent.element.tagName != 'a' && oEvent.element.tagName != 'A'){
# 					return;
# 				}
# 				var className = oEvent.element.className;
# 				for(i=0;i<elBannerList.length;i++){
# 					welBanner = $Element(elBannerList[i]);
# 					welPage = $Element(elBannerPagingList[i]);
# 					if(!welPage || !welBanner){
# 						break;
# 					}
# 					if(className.indexOf(elBannerList[i].className) >= 0){
# 						welBanner.show();
# 						if(!welPage.hasClass("on")){
# 							welPage.addClass("on");
# 						}
# 					} else{
# 						welBanner.hide();
# 						if(welPage.hasClass("on")){
# 							welPage.removeClass("on");
# 						}
# 					}
# 				}
# 				oEvent.stop();
# 				return false;
# 			}, this).attach(elBannerPaging, "click");
#
# 		}).attach(window, 'load');
# 	</script>
# </div>
# <div class="section_answer">
# <div class="container-fluid-content__left" id="left_content">
# <div class="stats_ranking_area" id="statsRankingArea">
# <div class="section_headings section_headings__step1">
# <h4 class="section_headings_title">많이 본 Q&amp;A</h4>
# <div class="side _ranking_base_date" id="rankingDate">17일 06시 기준</div>
# </div>
# <div class="ranking_section">
# <div class="ranking_list_area" id="rankingChart">
# <ul class="ranking_list">
# <li class="ranking_item _item_1">
# <span class="no">1</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=110408&amp;docId=437036038" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">대학교 순위 알려주세요</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=110408&amp;docId=437036038" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">대학교 순위 알려주세요 수원대학교,계명대학교,용인대학교,성결대학교,협성대학교,강남대학교,안양대학교,...</a>
# <span class="recommend_num">조회수 46</span><span class="reply_num">답변수 20</span>
# </li>
# <li class="ranking_item _item_2">
# <span class="no">2</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=110404&amp;docId=437162455" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">과학자와 수학자의 차이는 무엇인가요?</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=110404&amp;docId=437162455" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">과학자와 수학자의 차이는 무엇인가요?</a>
# <span class="recommend_num">조회수 40</span><span class="reply_num">답변수 1</span>
# </li>
# <li class="ranking_item _item_3">
# <span class="no">3</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=111301&amp;docId=310914081" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">(중딩)리만가설이 무엇인가요?? 말</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=111301&amp;docId=310914081" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">(중딩)리만가설이 무엇인가요?? 말 그자체로 소수인가요??? 모르겠어요ㅠㅠ..</a>
# <span class="recommend_num">조회수 39</span><span class="reply_num">답변수 3</span>
# </li>
# <li class="ranking_item _item_7" style="display: none;">
# <span class="no">7</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=1113&amp;docId=437127647" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">6명의 키를 구해주세요</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=1113&amp;docId=437127647" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">키가 큰 순서는 민찬&gt;민하&gt;나은&gt;채은&gt;호영&gt;소이 이며, 여섯명의 평균키는 151.5이고, 호영...</a>
# <span class="recommend_num">조회수 26</span><span class="reply_num">답변수 1</span>
# </li>
# <li class="ranking_item _item_8" style="display: none;">
# <span class="no">8</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=110404&amp;docId=437134987" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">지구과학 문제</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=110404&amp;docId=437134987" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">ㄴ에서 북서쪽으로 간다는데 제 긂으로 보면 부샤 동남 두쪽으로가는거아닌가요? 어ㅐ 북서로가는지좀 그림...</a>
# <span class="recommend_num">조회수 24</span><span class="reply_num">답변수 1</span>
# </li>
# <li class="ranking_item _item_9" style="display: none;">
# <span class="no">9</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=110503&amp;docId=437138796" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">대학 유급 국가장학금</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=110503&amp;docId=437138796" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">혹시 1학년 2학기를 유급하면 국가장학금은 1학년 1학기 성적으로 2학기를 다시 다닐수 있는건가요..? 대학...</a>
# <span class="recommend_num">조회수 21</span><span class="reply_num">답변수 1</span>
# </li>
# </ul>
# <ul class="ranking_list">
# <li class="ranking_item _item_4">
# <span class="no">4</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=4&amp;dirId=4020202&amp;docId=437125718" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">임대차법 질문</a>
# <a class="text" href="/qna/detail.naver?d1id=4&amp;dirId=4020202&amp;docId=437125718" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">예를들어서 제가 집을 매매했는데 그 집에 전주인이 1년월세로계약해서 살고있는 세입자가있는상황에서 세...</a>
# <span class="recommend_num">조회수 31</span><span class="reply_num">답변수 3</span>
# </li>
# <li class="ranking_item _item_5">
# <span class="no">5</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=8&amp;dirId=81302&amp;docId=437154274" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">편의점 택배 얼마나 걸릴까요</a>
# <a class="text" href="/qna/detail.naver?d1id=8&amp;dirId=81302&amp;docId=437154274" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">편의점 택배 받으려하는데 며칠동안 계속 멈춰있는데 이럴때는 어떻게 해야하나요 ??운송장 번호는 3643792...</a>
# <span class="recommend_num">조회수 27</span><span class="reply_num">답변수 1</span>
# </li>
# <li class="ranking_item _item_6">
# <span class="no">6</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=110503&amp;docId=437133793" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">유치원 정교사 자격증 2급</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=110503&amp;docId=437133793" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">아동보육과로 2년제 졸업 후 어린이집에 2년차 근무 중입니다. 유치원으로 근무를 희망해서 자격증을 따려...</a>
# <span class="recommend_num">조회수 26</span><span class="reply_num">답변수 19</span>
# </li>
# </ul>
# </div>
# <div class="paginate" id="rankingPaging">
# <a class="on" href="#" onclick="nhn.Kin.Utility.nClicks('hrk.page', '', '', event);" title="선택됨">1</a>
# <a href="#" onclick="nhn.Kin.Utility.nClicks('hrk.page', '', '', event);">2</a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	$Fn(function() {
# 		if (naver.kin.main.StatRanking !== undefined) {
# 			var oStatRanking = new naver.kin.main.StatRanking();
# 		}
# 	}, this).attach(window, 'load');
# </script>
# <div class="hottopic_keyword_area " id="hotTopicKeywordArea">
# <div class="title_group">
# <h4 class="title">지금 알아보세요!</h4>
# </div>
# <div class="hottopic_keyword_list_group">
# <ul class="hottopic_keyword_list">
# <li class="item"><a class="link" href="https://m.expert.naver.com/mobile/events/21581325779 " onclick="nhn.Kin.Utility.nClicks('hlk.link','','', event);" target="_blank">기묘년 새해운세</a></li>
# <li class="item"><a class="link" href="https://m.expert.naver.com/mobile/expert/category/home?groupCategoryId=294&amp;categoryId=157" onclick="nhn.Kin.Utility.nClicks('hlk.link','','', event);" target="_blank">매일 타로 상담</a></li>
# <li class="item"><a class="link" href="https://m.expert.naver.com/mobile/events/21681508667" onclick="nhn.Kin.Utility.nClicks('hlk.link','','', event);" target="_blank">심리상담소</a></li>
# <li class="item"><a class="link" href="https://m.expert.naver.com/mobile/expert/category/home?groupCategoryId=152&amp;categoryId=434" onclick="nhn.Kin.Utility.nClicks('hlk.link','','', event);" target="_blank">MBTI 검사</a></li>
# <li class="item"><a class="link" href="https://expert.naver.com/expert/introduction?tab=guide" onclick="nhn.Kin.Utility.nClicks('hlk.link','','', event);" target="_blank">엑스퍼트 신청</a></li>
# </ul>
# </div>
# </div>
# <span id="answer_wrap_top"></span>
# <div class="answer_wrap" id="main_content">
# <div class="title_area" id="noanswer_tab">
# <ul>
# <li class="tc-tab tc-selected"><a class="title on" href="#answer_wrap_top" id="contentsOfMain" onclick="nhn.Kin.Utility.nClicks('ldl.qna', '', '', event);">답변을 기다리는 질문<span class="blind _selected">선택됨</span></a></li>
# <li class="tc-tab"><a class="title" href="#answer_wrap_top" onclick="nhn.Kin.Utility.nClicks('ldl.con', '', '', event);">답변을 기다리는 관심질문</a></li>
# </ul>
# </div>
# <div>
# <div class="tc-panel tc-selected">
# <h4 class="blind">답변을 기다리는 질문</h4>
# <div class="content_wrap _noanswer_wrap">
# <div class="directory_area _qna_menu">
# <div class="directory_box _list_area">
# <ul class="directory_list _qna_list">
# <li class="on" dirid="0"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '0', '1', event);">전체<span class="blind _selected">질문 목록 선택됨</span></a></li>
# <li dirid="11"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '11', '2', event);">교육, 학문</a></li>
# <li dirid="1"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '1', '3', event);">컴퓨터통신</a></li>
# <li dirid="2"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '2', '4', event);">게임</a></li>
# <li dirid="3"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '3', '5', event);">엔터테인먼트, 예술</a></li>
# <li dirid="8"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '8', '6', event);">생활</a></li>
# <li dirid="7"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '7', '7', event);">건강</a></li>
# <li dirid="6"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '6', '8', event);">사회, 정치</a></li>
# <li dirid="4"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '4', '9', event);">경제</a></li>
# <li dirid="9"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '9', '10', event);">여행</a></li>
# <li dirid="10"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '10', '11', event);">스포츠, 레저</a></li>
# <li dirid="5"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '5', '12', event);">쇼핑</a></li>
# <li dirid="13"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '13', '13', event);">쥬니버Q&amp;A</a></li>
# <li dirid="12"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '12', '14', event);">지역&amp;플레이스</a></li>
# <li dirid="20"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.dir', '20', '15', event);">고민Q&amp;A</a></li>
# </ul>
# </div>
# <div class="directory_box _list_area _recommend_list_area">
# <h5>추천분야</h5>
# <ul class="directory_list _recommend_list">
# <li dirid="70404"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '70404', '1', event);">약 효능, 성분</a></li>
# <li dirid="70402"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '70402', '2', event);">의약외품</a></li>
# <li dirid="70403"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '70403', '3', event);">영양제, 건강보조식...</a></li>
# <li dirid="70401"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '70401', '4', event);">의약품</a></li>
# <li dirid="602060204"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '602060204', '5', event);">공갈, 협박</a></li>
# <li dirid="602060201"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '602060201', '6', event);">살인</a></li>
# <li dirid="602060203"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '602060203', '7', event);">폭행</a></li>
# <li dirid="602060202"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '602060202', '8', event);">강도</a></li>
# <li dirid="61303"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '61303', '9', event);">사람과 그룹</a></li>
# <li dirid="61302"><a href="#" onclick="nhn.Kin.Utility.nClicks('ldl_nlg.rec', '61302', '10', event);">외국사회문화</a></li>
# </ul>
# </div>
# </div>
# <span class="border"></span>
# <div class="content_area _dir_content" style="display:none;">
# <div class="heading_area _dir_content_title" style="display:none;">
# <h5 class="tit ellipsis _heading_title">
# <a href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('nql_nlg.dirn', '', '', event);"><strong>전체</strong> <span class="blind">의 답변을 기다리는 질문 바로가기</span></a>
# </h5>
# <a class="btn_line _ros _btn_add_interest" dirid="0" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.cdir', '0', '', event);" style="display:none"><span><i class="ico_plus sp_common"></i>관심분야 추가</span></a>
# <div class="search_area _heading_search" onclick="nhn.Kin.Utility.nClicks('nql_nlg.search', '', '', event);">
# <input class="search_input _search_input" title="검색어 입력" type="text"/>
# <a class="ico_search sp_common _search_button" href="#">검색</a>
# </div>
# <div class="sort_list_group _option">
# <div class="sort_list_group_left">
# <div class="view_type_wrap">
# <p class="blind">보기옵션 선택</p>
# <ul class="view_type_list _view_type_list" role="tablist">
# <!-- [D]
# 									1) 클로바앱 질문(선택안되게): is_disabled 클래스 추가 / aria-disabled="true" 추가
# 									2) tab 요소(ul.view_type_list > li > a) click 이벤트시 동작
# 										- 선택된 탭일 경우: on 클래스 추가 및 aria-selected="true"로 변경
# 										- 선택되지 않은 탭일 경우: on 클래스 제거 및 aria-selected="false"로 변경
# 										- 비활성화된 탭일 경우: is_disabled 클래스 추가 및 aria-disabled="true" 속성 추가
# 										- 활성화된 탭일 경우: is_disabled 클래스 제거 및 aria-disabled 속성 제거
# 									3) tab 요소(ul.view_type_list > li > a)와 하단 div.answer_list 요소 연결
# 										- 미리보기형 탭은 미리보기형 목록과, 제목형 탭은 제목형 목록과 각각 연결
# 										- a 요소의 aria-controls=""와 div 요소의 id=""에 동일한 id 값 제공
# 								-->
# <li class="_preview"><a aria-controls="questionListTypePreview" aria-selected="true" class="type_preview _previewTypeBtn on" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.preview', '', '', event);" role="button">미리보기형</a></li>
# <li class="_onlyTitle"><a aria-controls="questionListTypeTitle" aria-selected="false" class="type_title _onlyTitleTypeBtn" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.title', '', '', event);" role="button">제목형</a>
# <div class="tooltip _previewTypeTooltipLayer" style="display:none">
# <span class="sp_common arrow"></span>
# <div class="inner">
# <p class="blind">안내</p>
# 										제목만 모아서 많은 질문을<br/> 한 번에 볼 수 있어요!
# 										<a class="sp_common btn_close _previewTypeTooltipLayerClose" href="#">닫기</a>
# </div>
# </div>
# </li>
# </ul>
# <div class="select_area _countPerPageSelectBox">
# <a class="btn_select _selectedCountPerPageValue" href="#">10개 보기 <span class="ico_arrow sp_common"></span></a>
# <p class="blind">보기 개수 선택</p>
# <ul class="select_list _countPerPageListArea">
# <li class="_countPerPage _param('5')"><a class="_countPerPageValue _param('5')" href="#">5개 보기</a></li>
# <li class="_countPerPage _param('10') on"><a class="_countPerPageValue _param('10')" href="#">10개 보기</a></li>
# <li class="_countPerPage _param('15')"><a class="_countPerPageValue _param('15')" href="#">15개 보기</a></li>
# <li class="_countPerPage _param('20')"><a class="_countPerPageValue _param('20')" href="#">20개 보기</a></li>
# <li class="_countPerPage _param('25')"><a class="_countPerPageValue _param('25')" href="#">25개 보기</a></li>
# <li class="_countPerPage _param('30')"><a class="_countPerPageValue _param('30')" href="#">30개 보기</a></li>
# <li class="_countPerPage _param('50')"><a class="_countPerPageValue _param('50')" href="#">50개 보기</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="sort_list_group_right">
# <p class="blind">정렬 옵션 선택</p>
# <ul class="sort_list_module _sortOptionList">
# <li class="is_active _answer"><a aria-selected="true" class="_sort_option _param('answer')" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.answer', '', '', event);" role="button"><i class="ico_sort _sort_option _param('answer')"></i>답변적은순</a></li>
# <li class="_firstFlag"><a aria-selected="false" class="_sort_option _param('firstFlag')" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.newask', '', '', event);" role="button"><i class="ico_sort _sort_option _param('firstFlag')"></i>첫질문</a></li>
# <li class="_recent"><a aria-selected="false" class="_sort_option _param('recent')" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.latest', '', '', event);" role="button"><i class="ico_sort _sort_option _param('recent')"></i>최신순</a></li>
# <li class="_betPoint"><a aria-selected="false" class="_sort_option _param('betPoint')" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.point', '', '', event);" role="button"><i class="ico_sort _sort_option _param('betPoint')"></i>내공높은순</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="answer_list _noanswer_list" role="tabpanel" style="display:none;">
# </div>
# <div class="answer_list _dir_content_noanswer_noresult" style="display:none;">
# <div class="no_data">
# <p>선택하신 분야에 등록된 답변을 기다리는 질문이 없습니다.</p>
# </div>
# </div>
# <div class="paging_area paging_control_type1 _pagingArea" id="pagingArea0" style="display:none;">
# </div>
# </div>
# <div class="content_area _dir_content_error" style="display:none;">
# <div>
# <div class="_dir_content_noanswer_noresult view_all_question view_all_question2">
# <div class="cont">
# <p class="tit"><strong>요청하신 정보를 일시적으로 불러올 수 없습니다. <br/>잠시 후 다시 시도해 주세요.</strong></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tc-panel">
# <h4 class="blind">답변을 기다리는 관심질문</h4>
# <div class="content_wrap _noanswer_wrap">
# <div class="directory_area _int_menu">
# <div class="set_box multi">
# <a class="btn_setting _interest_setting_btn" href="#" onclick="nhn.Kin.Utility.nClicks('ldl_lgd.setmy', '', '', event);" target="_blank"><span><i class="sp_common ico_set"></i>관심설정</span></a>
# <div class="help_wrap">
# <a class="ico_help _interest_setting_help_btn" href="#"><img alt="도움말" height="12" src="https://ssl.pstatic.net/static/kin/09renewal/new_master/ico_help_v2.gif" width="12"/>
# </a>
# <div class="tooltip _interest_setting_help_layer" style="display:none;">
# <span class="sp_common arrow"></span>
# <div class="inner">
# <p class="tit">관심설정을 하면?</p>
# <p>내가 설정한 관심분야/지역/키워드에 답변을 기다리는 질문이 등록되면 알림을 받을 수 있습니다.</p>
# <p>최초 관심설정 시 <strong class="point">내공 30점</strong>도 드려요! 지금 바로 관심설정 해보세요.</p>
# <a class="sp_common btn_close _interest_setting_help_layer_close" href="#">닫기</a>
# </div>
# </div>
# </div>
# </div>
# <div class="directory_box _list_area _interest_list_area">
# <h5>관심분야</h5>
# <ul class="directory_list _interest_list" style="display:none;">
# </ul>
# <ul class="directory_list _no_interest_list">
# <li>관심분야가 없습니다.</li>
# </ul>
# </div>
# <div class="directory_box _list_area _local_list_area">
# <h5>관심지역</h5>
# <ul class="directory_list _local_list" style="display:none;">
# </ul>
# <ul class="directory_list _no_local_list">
# <li>관심지역이 없습니다.</li>
# </ul>
# </div>
# <div class="directory_box _list_area _keyword_list_area">
# <h5>관심키워드</h5>
# <ul class="directory_list _keyword_list" style="display:none;">
# </ul>
# <ul class="directory_list _no_keyword_list">
# <li>관심키워드가 없습니다.</li>
# </ul>
# </div>
# </div>
# <span class="border"></span>
# <div class="content_area _dir_content" style="display:none;">
# <div class="heading_area _dir_content_title">
# <h5 class="tit ellipsis _heading_title">
# <a href="/myinfo/interest.naver" onclick="nhn.Kin.Utility.nClicks('nql_nlg.dirn', '', '', event);"><strong>내 관심분야</strong> <span class="blind">의 답변을 기다리는 질문 바로가기</span></a>
# </h5>
# <div class="set_recommend _tag_recommend" style="display:none;">
# </div>
# <div class="search_area _heading_search" onclick="nhn.Kin.Utility.nClicks('nql_nlg.search', '', '', event);">
# <input class="search_input _search_input" title="검색어 입력" type="text"/>
# <a class="ico_search sp_common _search_button" href="#">검색</a>
# </div>
# <div class="_map_area map_area" style="display:none">
# </div>
# <script type="text/javascript">
# 	try {document.execCommand('BackgroundImageCache', false, true);} catch(e) {}
# </script>
# <link href="https://ssl.pstatic.net/static/maps/openapi_map/maps_openapi.css" rel="stylesheet" type="text/css">
# <div class="sort_list_group _option">
# <div class="sort_list_group_left">
# <ul class="sort_tab _keyword_tag_tab" style="display:none">
# <li class="on _keyword_tab"><a class="_keyword_tab" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.iktext', '', '', event);">제목+본문</a></li>
# <li class="_tag_tab"><a class="_tag_tab" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.iktag', '', '', event);">태그</a></li>
# </ul>
# <div class="view_type_wrap">
# <ul class="view_type_list _view_type_list">
# <p class="blind">보기옵션 선택</p>
# <li class="_preview"><a aria-controls="questionListTypePreview" aria-disabled="false" aria-selected="true" class="type_preview _previewTypeBtn on" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.preview', '', '', event);" role="button">미리보기형</a></li>
# <li class="_onlyTitle"><a aria-controls="questionListTypeTitle" aria-disabled="true" aria-selected="false" class="type_title _onlyTitleTypeBtn" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.title', '', '', event);" role="button">제목형</a>
# <div class="tooltip _previewTypeTooltipLayer" style="display:none;">
# <span class="sp_common arrow"></span>
# <div class="inner">
# <p class="blind">안내</p>
# 										제목만 모아서 많은 질문을<br/> 한 번에 볼 수 있어요!
# 										<a class="sp_common btn_close _previewTypeTooltipLayerClose" href="#">닫기</a>
# </div>
# </div>
# </li>
# </ul>
# <div class="select_area _countPerPageSelectBox">
# <a class="btn_select _selectedCountPerPageValue" href="#">10개 보기 <span class="ico_arrow sp_common"></span></a>
# <p class="blind">보기 개수 선택</p>
# <ul class="select_list _countPerPageListArea">
# <li class="_countPerPage _param('5')"><a class="_countPerPageValue _param('5')" href="#">5개 보기</a></li>
# <li class="_countPerPage _param('10') on"><a class="_countPerPageValue _param('10')" href="#">10개 보기</a></li>
# <li class="_countPerPage _param('15')"><a class="_countPerPageValue _param('15')" href="#">15개 보기</a></li>
# <li class="_countPerPage _param('20')"><a class="_countPerPageValue _param('20')" href="#">20개 보기</a></li>
# <li class="_countPerPage _param('25')"><a class="_countPerPageValue _param('25')" href="#">25개 보기</a></li>
# <li class="_countPerPage _param('30')"><a class="_countPerPageValue _param('30')" href="#">30개 보기</a></li>
# <li class="_countPerPage _param('50')"><a class="_countPerPageValue _param('50')" href="#">50개 보기</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="sort_list_group_right">
# <p class="blind">정렬 옵션 선택</p>
# <ul class="sort_list_module _sortOptionList">
# <li class="is_active _answer"><a aria-selected="false" class="_sort_option _param('answer')" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.answer', '', '', event);" role="button"><i class="ico_sort _sort_option _param('answer')"></i>답변적은순</a></li>
# <li class="_firstFlag"><a aria-selected="false" class="_sort_option _param('firstFlag')" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.newask', '', '', event);" role="button"><i class="ico_sort _sort_option _param('firstFlag')"></i>첫질문</a></li>
# <li class="_recent"><a aria-selected="false" class="_sort_option _param('recent')" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.latest', '', '', event);" role="button"><i class="ico_sort _sort_option _param('recent')"></i>최신순</a></li>
# <li class="_betPoint"><a aria-selected="false" class="_sort_option _param('betPoint')" href="#" onclick="nhn.Kin.Utility.nClicks('nql_nlg.point', '', '', event);" role="button"><i class="ico_sort _sort_option _param('betPoint')"></i>내공높은순</a></li>
# </ul>
# </div>
# </div>
# </link></div>
# <div class="heading_area _dir_content_title_recommend" style="display:none">
# <h5 class="tit ellipsis"><strong>추천 관심분야</strong></h5>
# <span class="tit_desc">관심분야, 관심지역, 관심키워드를 설정하면 홈과 프로필에서 관심있는 분야의 질문을 바로 확인할 수 있습니다.<br/>관심분야의 답변 활동을 통해 관심분야의 전문가로 활동해 보세요.</span>
# </div>
# <div class="answer_list _noanswer_list" role="tabpanel" style="display:none;">
# </div>
# <div class="answer_list _dir_content_noanswer_noresult" style="display:none;">
# <div class="no_data">
# <p>선택하신 분야에 등록된 답변을 기다리는 질문이 없습니다.</p>
# </div>
# </div>
# <div class="paging_area paging_control_type1 _pagingArea" id="pagingArea1" style="display:none;">
# </div>
# </div>
# <div class="content_area _dir_content_error" style="display:none;">
# <div>
# <div class="_dir_content_noanswer_noresult view_all_question view_all_question2">
# <div class="cont">
# <p class="tit"><strong>요청하신 정보를 일시적으로 불러올 수 없습니다. <br/>잠시 후 다시 시도해 주세요.</strong></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="article_donations article_donations_square _happybeanArea" id="happybean_content" style="display:none;">
# <div class="section_headings section_headings__step1">
# <h4 class="section_headings_title">나눔, 함께해요</h4>
# </div>
# <div class="donations_list donations_list__type1 _happybeanDonateBoxListArea">
# </div>
# <div class="apply_info apply_info__type1 _happybeanInfoArea">
# </div>
# </div>
# <script id="happybeanDonateBoxListTpl" type="text/template">
# 	<a href="{=pcUrl}" class="donations_list__item" target="_blank" onClick="nhn.Kin.Utility.nClicks('hpy.donate','','',event);">
# 		<div class="thumbnail">
# 			<img src="{=dthumbImageUrl}" width="160" height="120" alt="{=escapeTitle}">
# 		</div>
# 		<p class="title">{=title}</p>
# 		<p class="association">{=happylogName}</p>
# 		<div class="donations_list__status">
# 			<div class="donations_list__progress_bar">
# 				<span style="width:{=progressRate}%"></span>
# 			</div>
# 			<div class="donations_list__count">
# 				<span class="donations_list__fund"><span class="blind">총 기부금액</span>{=currentAmount}원</span>
# 				<span class="donations_list__percent"><span class="blind">후원률</span>{=progressRate}%</span>
# 			</div>
# 		</div>
# 	</a>
# </script>
# <script id="happybeanInfoTpl" type="text/template">
# 	<p class="text"><i class="sp_common ico_alert__green_small" aria-label="주의"></i>해피빈 사이트에서 진행 중인 나눔기부 정보입니다. 지식iN 활동을 통해 적립한 해피빈 콩을 기부해보세요.<a href="{=morePcUrl}" target="_blank" class="more" title="네이버 해피빈으로 이동" onClick="nhn.Kin.Utility.nClicks('hpy.more','','',event);">더보기</a></p>
# </script>
# </div>
# <!-- {{{ -->
# <script id="titleAreaTpl" type="text/template">
# 	{if type == 'local'}
# 		<a href="/qna/list.naver?dirId={=dirId}" onclick="nhn.Kin.Utility.nClicks('{=sClickAreaName}.dirn', '{=dirId}', '', event);"><strong>{=title}</strong> <span class="blind">의 답변을 기다리는 질문 바로가기</span></a>
# 	{elseif type == 'keyword' || type == 'tag'}
# 		{if dirId == null || title == '내 관심키워드'}
# 			<a href="/myinfo/interestKeyword.naver?query=" onclick="nhn.Kin.Utility.nClicks('{=sClickAreaName}.dirn', '', '', event);"><strong>내 관심키워드</strong> <span class="blind">의 답변을 기다리는 바로가기</span></a>
# 		{else}
# 			<a href="/search/noAnswerList.naver?query={=title}" onclick="nhn.Kin.Utility.nClicks('{=sClickAreaName}.dirn', '', '', event);"><strong>{=encodedTitle}</strong> <span class="blind">의 답변을 기다리는 바로가기</span></a>
# 		{/if}
# 	{elseif type == 'interest'}
# ...
# <a class="tag _nclicks:sbn.btn" href="/tag/tagDetail.naver?tag=%EC%8A%A4%EB%B0%8D&amp;listType=answer">#스밍</a>
# </div>
# </div>
# <div class="aside_notice">
# <div class="inner">
# <h4>공지사항</h4>
# <ul class="notice_list">
# <li>
# <a class="tit _nclicks:not.list" href="https://blog.naver.com/kin_friend/222985535008" target="_balnk">지식iN 올해 첫 미션! 토끼 배지 모으기</a>
# <span class="date_info">2023.01.16.</span>
# </li>
# <li>
# <a class="tit _nclicks:not.list" href="https://blog.naver.com/kin_friend/222961155803" target="_balnk">지식iN 서비스 운영정책 변경 안내</a>
# <span class="date_info">2022.12.22.</span>
# </li>
# <li>
# <a class="tit _nclicks:not.list" href="https://blog.naver.com/kin_friend/222972512505" target="_balnk">지식파트너 약관 개정 안내</a>
# <span class="date_info">2023.01.02.</span>
# </li>
# </ul>
# <a class="more no_underline _nclicks:not.more" href="http://blog.naver.com/kin_friend">더보기</a>
# </div>
# </div>
# <div class="aside_campaign" id="asideCampaign">
# <h4>캠페인</h4>
# <div class="campaign type2">
# <a class="txt_area _nclicks:evt.list,r:0" href="https://kin.naver.com/partnercenter/index.nhn" target="_blank">
# <span class="_campaignTitle">공식답변을 편리하게 신청하는 지식파트너센터</span>
# <i class="ico_campaign"><img alt="공식답변을 편리하게 신청하는 지식파트너센터" src="https://ssl.pstatic.net/static/kin/09renewal/new_master/campaign2.png"/></i>
# </a>
# </div>
# <div class="campaign type2">
# <a class="txt_area _nclicks:evt.list,r:1" href="https://kin.naver.com/volunteer/index.nhn" target="_blank">
# <span class="_campaignTitle">지식나눔의 기쁨과 봉사활동 시간 인정까지!</span>
# <i class="ico_campaign"><img alt="지식나눔의 기쁨과 봉사활동 시간 인정까지!" src="https://ssl.pstatic.net/static/kin/09renewal/new_master/campaign1.png"/></i>
# </a>
# </div>
# <div class="link_area">
# <a class="_nclicks:evt.help no_underline" href="https://help.naver.com/alias/kin/kinmain.naver" target="_blank">지식iN 도움말</a>
# <a class="_nclicks:evt.blog no_underline" href="http://blog.naver.com/kin_friend/" target="_blank">지식iN 공식블로그</a>
# </div>
# </div>
# <script type="text/javascript">
# $Fn(function() {
# 	var elList = $$('span._campaignTitle',$("asideCampaign"));
# 	if(!elList ){
# 		return;
# 	}
#
# 	for(var i=0;i<elList.length;i++){
# 		wel = $Element(elList[i]);
# 		if(elList[i].scrollHeight > elList[i].clientHeight){
# 			// 2줄일때
# 			wel.parent().parent().removeClass("type2");
# 			wel.parent().parent().addClass("type1");
# 		}
# 		wel = $Element(elList[i]);
# 	}
# }).attach(window, 'load');
# </script>
# <div class="aside_statistics">
# <h4>오늘의 질문과 답변</h4>
# <div class="stats stats_today">
# <span class="blind">질문</span><strong class="num">33,955</strong><em class="slash sp_common">/</em><span class="blind">답변</span><strong class="num">68,390</strong>
# <p class="date_info">2023.01.17.</p>
# </div>
# <h4>누적 답변수</h4>
# <div class="stats stats_accum">
# <strong class="num">528,251,944</strong>
# <p class="date_info">since 2002</p>
# </div>
# </div>
# <div class="aside_bingo_banner">
# <a class="_nclicks:sbn.bn02" href="/bingo/bingoHome.naver">
# <img alt="초보 사용자 가이드 지식iN 빙고" height="95" src="https://ssl.pstatic.net/static/kin/09renewal/banner_bingo_220207.png" width="240"/>
# </a>
# </div>
# <div class="aside_roulette_banner">
# <a class="_nclicks:sbn.bn03" href="/roulette/home.naver">
# <img alt="네이버페이 최대 1만원 지식iN 룰렛" height="95" src="https://ssl.pstatic.net/static/kin/09renewal/banner_roulette_220207.png" width="240"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid-content-etc">
# <div class="section_partner">
# <div class="partner_wrap" id="expertAnswerArea">
# <div class="inner">
# <h4 class="tit">전문가 답변</h4>
# <ul class="partner_list _logoList">
# <li>
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=35" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1577433368081.png">
# <img alt="닥톡 치과의사" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1577433368081.png" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=TAXACC&amp;orgId=37" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1529028517711.gif">
# <img alt="로시컴" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1529028517711.gif" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=CUSTOMSBROKER&amp;orgId=38" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1535418140064.jpg">
# <img alt="한국관세사회" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1535418140064.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=ANIMALDOCTOR&amp;orgId=39" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1539929982572.jpg">
# <img alt="펫닥" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1539929982572.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=40" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1542690209088.jpg">
# <img alt="대한성형외과의사회" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1542690209088.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=41" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1548739450485.jpg">
# <img alt="하이닥 한의사" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1548739450485.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=42" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1548740053624.jpg">
# <img alt="하이닥 치과의사" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1548740053624.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=ANIMALDOCTOR&amp;orgId=43" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1548740156706.jpg">
# <img alt="하이닥 수의사" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1548740156706.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=44" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1553256211619.jpg">
# <img alt="인터엠디컴퍼니" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1553256211619.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=46" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1572747352163.jpg">
# <img alt="생활법률연구회" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1572747352163.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=PHARMACIST&amp;orgId=47" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1577433243776.png">
# <img alt="닥톡 약사" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1577433243776.png" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=48" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1575510789923.jpg">
# <img alt="정신건강연구소" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1575510789923.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=DIETITIAN&amp;orgId=49" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1577095190390.jpg">
# <img alt="닥톡 영양사" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1577095190390.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=TAXACC&amp;orgId=51" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1629854957744.jpg">
# <img alt="생활법률연구회" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1629854957744.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=1" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1381483134136.jpg">
# <img alt="대한의사협회" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1381483134136.jpg" width="100"/>
# </a>
# </li>
# <li>
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=2" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1475634151878.jpg">
# <img alt="하이닥" height="29" src="https://kin-phinf.pstatic.net/exphoto/organization/organization_1475634151878.jpg" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=3" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1287734618684.jpg">
# <img alt="대한치과의사협회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=4" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1395291303193.jpg">
# <img alt="대한한의사협회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=6" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1259396007085.gif">
# <img alt="서울지방변호사회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LABOR&amp;orgId=7" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1259396053196.gif">
# <img alt="한국공인노무사회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=9" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1267074399213.jpg">
# <img alt="언론중재위원회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=11" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1444027426598.jpg">
# <img alt="로시컴" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=13" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1302074470229.jpg">
# <img alt="세계한인변호사회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=15" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1300340167068.jpg">
# <img alt="대한산부인과의사회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=16" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1310027408603.jpg">
# <img alt="김앤장법률사무소" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=17" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1311215032035.jpg">
# <img alt="원자력병원" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=18" rel="https://kin-phinf.pstatic.net/storage/organization/organization_1312425110183.jpg">
# <img alt="대한변리사회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LABOR&amp;orgId=19" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1444027404236.jpg">
# <img alt="로시컴" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=ANIMALDOCTOR&amp;orgId=20" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1412673470438.jpg">
# <img alt="이리온" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=PHARMACIST&amp;orgId=21" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1475634107641.jpg">
# <img alt="하이닥" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=PHARMACIST&amp;orgId=22" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1415845403815.jpg">
# <img alt="대한약사회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=TAXACC&amp;orgId=23" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1439877571628.jpg">
# <img alt="한국세무사회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=ANIMALDOCTOR&amp;orgId=24" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1460970639379.jpg">
# <img alt="한국동물암센터" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=ANIMALDOCTOR&amp;orgId=25" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1460970817367.jpg">
# <img alt="N동물의료센터" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=ANIMALDOCTOR&amp;orgId=26" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1462263060879.jpg">
# <img alt="헬릭스동물메디컬센터" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=27" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1473299268627.jpg">
# <img alt="대한법률구조공단" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=DIETITIAN&amp;orgId=28" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1475634209552.jpg">
# <img alt="하이닥" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=29" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1483606217284.jpg">
# <img alt="로톡" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=LAWYER&amp;orgId=31" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1501638375975.jpg">
# <img alt="법률N미디어" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=32" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1520573476852.jpg">
# <img alt="대한피부과의사회" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=33" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1577433291427.png">
# <img alt="닥톡 의사" height="29" width="100"/>
# </a>
# </li>
# <li style="display:none">
# <a href="/people/expert/index.naver?type=DOCTOR&amp;orgId=34" rel="https://kin-phinf.pstatic.net/exphoto/organization/organization_1577433329185.png">
# <img alt="닥톡 한의사" height="29" width="100"/>
# </a>
# </li>
# </ul>
# <div class="nav_area">
# <a class="prev sp_common _prev" href="#">이전</a>
# <a class="next sp_common _next" href="#">다음</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# $Fn(function() {
# 	var oExpertOrganizations = new naver.kin.main.ExpertOrganizations();
# }).attach(window, 'load');
# </script>
# </div>
# </div>
# <script src="https://ssl.pstatic.net/static.kin/static/pc/20221207140750/js/min/kin.home.js" type="text/javascript"></script>
# <div class="footer_wrap">
# <div class="footer">
# <h2 class="blind">하위영역</h2>
# <div class="footer_menu">
# <a class="_nclicks:fot.agreement" href="http://www.naver.com/rules/service.html" target="_blank">네이버 이용약관</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.policy" href="/common/guide.naver?query=p1" target="_blank">지식iN 서비스 운영정책</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.privacy" href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.claim" href="http://inoti.naver.com/inoti/main.nhn" target="_blank">게시중단요청서비스</a>
# <span class="f_bar">|</span>
# <a class="_nclicks:fot.help" href="https://help.naver.com/alias/kin/kinmain.naver" target="_blank">지식iN 고객센터</a>
# </div>
# <p class="copyright"><a class="footer_logo sp_common" href="http://www.naver.com" target="_blank">NAVER</a>Copyright © <strong><a class="logo _nclicks:fot.nhncorp" href="https://www.navercorp.com" target="_blank">NAVER Corp.</a></strong> All Rights Reserved.</p>
# </div>
# </div>
# <script type="text/javascript">
# 		lcs_do();
# 	</script>
# </div>
# </body>
# </html>

# %%
soup.text #soup.get_text()
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\n\tvar pcDomain = "kin.naver.com";\n\tvar pcDomainWithProtocol = "https://kin.naver.com";\n\tvar pcKinServiceProtocol = "https";\n\n\tvar mobileDomain = "m.kin.naver.com";\n\tvar mobileDomainWithProtocol = "https://m.kin.naver.com";\n\tvar mobileKinServiceProtocol = "https";\n\n\tvar uploadDomain = "upload.kin.naver.com";\n\tvar uploadDomainWithProtocol = "https://upload.kin.naver.com";\n\tvar uploadKinServiceProtocol = "https";\n\n\n\n\n\n\n\n\n\n\n\n\n\t네이버 지식iN\n\n\n\nif ( typeof window.nhn  == "undefined" ) window.nhn = {};\nif ( typeof window.naver  == "undefined" ) window.naver = {};\nnhn.isLogin = false;\nnhn.isJunior = ("N"=="Y");\nnhn.isKinUser = false;\nnhn.isPortableDevice = false;\nnhn.jsDir = \'https://ssl.pstatic.net/static.kin/static/pc/20221207140750/js/min\';\n\nvar g_ssc = ("kin.home" == "") ? "kin.temp" : "kin.home";\nvar ccsrv="cc.naver.com";\n\n\nvar kinRos = {\n\tbIsNoticeDisplay : ("false" == "" || "false" == "false") ? false : true,\n\tbIsActionNoticeDisplay : ("false" == "" || "false" == "false") ? false : true\n\n};\n\n\n\n\n\nvar standardReportPopupUrl = "https://srp2.naver.com/report";\n\n\n\n\n\n\n\n\n메인 메뉴 바로가기\n본문 바로가기\n\n\n\n권장 브라우저 업데이트 안내\n\n\n권장 브라우저 안내\n\n\n혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?\n새롭게 바뀐 지식iN Q&A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! 업데이트하기 \n\n\n\n\n\t// IE8 이하이면 브라우저 버전을 올려달라는 배너를 노출한다.\n\t$Fn(function() {\n\t\tvar oAgent = jindo.$Agent().navigator();\n\t\tif (oAgent.ie && (oAgent.version >= 6 && oAgent.version < 9)) {\n\t\t\tif (typeof naver.kin.SimpleBanner !== "undefined") {\n\t\t\t\tvar oIeUpdateBanner = new naver.kin.SimpleBanner({\n\t\t\t\t\tsBannerId: "ieUpdateBannerArea"\n\t\t\t\t});\n\t\t\t}\n\t\t}\n\t}, this).attach(document, \'domready\');\n\n\n\n\n\nNAVER\n\n\n\n지식iN\n\n검색영역\n\n\n지식인 검색\n\n\n\n자동완성 열기\n\n\n\n\n지식iN 검색\n\n\n\n\n\n\n\n\n\neXpert\n\n\n\n\n상담 목록\n\nNEW\n\n\n\n\t\t\t\t\t\t\t\t판매한 상품\n\t\t\t\t\t\t\t\tNEW\n\n\n\t\t\t\t\t\t\t\t구매한 상품\n\t\t\t\t\t\t\t\tNEW\n\n\n\n\n\n\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tvar gnb_service = "kin";\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tvar gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tvar gnb_login = encodeURIComponent(location.href || \'https://kin.naver.com\');\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tvar gnb_template = "gnb_utf8";\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tvar gnb_item_hide_option = 0;\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\n\n\n\n\n실시간 공지사항\n\n\n\n새소식\n2023년 엑스퍼트 전문가 되자!\n\n\n\n\n새소식\n지존도 이제 엑스퍼트\n\n\n\n\n새소식\n\t\t\t\t\t\t\t\t\t\t\t전문가가 필요할 때! 엑스퍼트.\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n메인 메뉴\n\n\n홈\n\n\nQ&A\n\n교육, 학문\n컴퓨터통신\n게임\n엔터테인먼트, 예술\n생활\n건강\n사회, 정치\n경제\n여행\n스포츠, 레저\n쇼핑\n쥬니버Q&A\n지역&플레이스\n고민Q&A\n오픈사전\n\n\n\n답변하기\n\n\n지식기부\n\n\n사람들\n\n\n베스트\n\n\n명예의전당\n\n\n|\n프로필\n\n\n파트너센터\n\n\n룰렛\n\n\n질문하기\n\n\n\n\n\t\n\t$Fn(function() {\n\t\tnew naver.kin.LNB({\n\t\t\t\'questionType\' : \'\'\n\t\t});\n\t}).attach(window, \'load\');\n\n\tvar GNB_BRIGHTNESS_VALUE = {\n\t\tDARK_ICON : 0,\n\t\tDARK_ICON_AND_TRANSPARENCY : 1,\n\t\tBRIGHT_ICON_AND_TRANSPARENCY : 2,\n\t\tBRIGHT_ICON : 3\n\t};\n\t\n\tvar GNB_ITEM_HIDE_OPTION_BIT_VALUE = {\n\t\tDEFAULT : 0,\n\t\tHIDE_LOGIN_BTN : 1,\n\t\tHIDE_USER_LAYER : 2,\n\t\tHIDE_NAVER_ME_AREA : 4,\n\t\tHIDE_MAIL_ALARM_AREA : 8,\n\t\tHIDE_PROFILE_IMAGE : 16,\n\t\tSHOW_BENEFIT_FOR_STAFF_MEMBER : 32\n\t};\n\n\t\n\tvar smartSearch = "";\n\t\n\tvar gnb_service = "kin";\n\t\n\tvar gnb_logout = encodeURIComponent("https://nid.naver.com/nidlogin.logout");\n\t\n\tvar gnb_login = encodeURIComponent(location.href || \'https://kin.naver.com\');\n\t\n\tvar gnb_template = "gnb_utf8";\n\t\n\tvar gnb_item_hide_option = GNB_ITEM_HIDE_OPTION_BIT_VALUE.DEFAULT;\n\t\n\t\n\t\n\t\n\n\t$Fn(function() {\n\t\t\n\t\tgetGNB();\n\t\t\n\t\tvar bIsGnbClicked = false;\n\t\t\n\t\t\n\t\t$Fn(function (we) {\n\t\t\tif (!bIsGnbClicked) {\n\t\t\t\tgnbAllLayerClose();\n\t\t\ ...

# %%
title = soup.find('title') # 사용자가 지정한 태그를 찾아준다. (가장 첫번째 태그만 찾아준다.)
print(title) # title 이라는 tag를 추출해준다.
print(title.get_text()) # 데이터에서 태그를 제거하고 텍스트만 출력해준다.
# Out:
# <title>
# 	네이버 지식iN
# </title>
#
# 	네이버 지식iN

# %%
# ul 태그 출력: 사용자가 지정한 태그의 가장 첫번째 태그만 출력
uls=soup.find('ul')
uls
# Out:
# <ul class="rolling-notice__list _rolling_banner" id="listNotice">
# <li class="rolling-notice__item _rollingItem" data-start-time="2021-10-26 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://expert.naver.com/expert/introduction?tab=guide#join" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">2023년 엑스퍼트 전문가 되자!</span>
# </a>
# </li>
# <li class="rolling-notice__item _rollingItem" data-start-time="2022-08-31 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://expert.naver.com/expert/introduction?tab=guide#join" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# <span class="text-color--secondary">지존도 이제 엑스퍼트</span>
# </a>
# </li>
# <li class="rolling-notice__item _rollingItem" data-start-time="2022-12-06 00:00:00" style="display:none;">
# <a class="rolling-notice__link" href="https://m.expert.naver.com/" onclick="nhn.Kin.Utility.nClicks('STA.event', '', '', event);">
# <i class="icon_new_red _newMark" style="display:none;"><span class="blind">새소식</span></i>
# 											전문가가 필요할 때! 엑스퍼트.
# 									</a>
# </li>
# </ul>

# %%
# 여러개가 적용된 태그 찾기(리스트 형식으로 출력)
uls=soup.find_all('ul') # 페이지의 모든 ul 태그값 출력
uls[1]
# Out:
# <ul class="nav_list" id="au_lnb" role="menubar">
# <li class="menu" role="presentation">
# <a class="item" href="/index.naver" id="au_lnb_home" onclick="nhn.Kin.Utility.nClicks('LNB.home', '', '', event);" role="menuitem" tabindex="0"><em>홈</em></a>
# </li>
# <li class="menu" role="presentation">
# <a aria-expanded="false" aria-haspopup="true" class="item" href="/qna/list.naver" onclick="nhn.Kin.Utility.nClicks('LNB.qna', '', '', event);" role="menuitem" tabindex="-1"><em>Q&amp;A</em></a>
# <ul class="nav_sub_list _lnbSubMenu" role="menu">
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=11" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '11', '1', event);" role="menuitem" tabindex="-1">교육, 학문</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=1" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '1', '2', event);" role="menuitem" tabindex="-1">컴퓨터통신</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=2" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '2', '3', event);" role="menuitem" tabindex="-1">게임</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=3" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '3', '4', event);" role="menuitem" tabindex="-1">엔터테인먼트, 예술</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=8" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '8', '5', event);" role="menuitem" tabindex="-1">생활</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=7" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '7', '6', event);" role="menuitem" tabindex="-1">건강</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=6" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '6', '7', event);" role="menuitem" tabindex="-1">사회, 정치</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=4" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '4', '8', event);" role="menuitem" tabindex="-1">경제</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=9" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '9', '9', event);" role="menuitem" tabindex="-1">여행</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=10" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '10', '10', event);" role="menuitem" tabindex="-1">스포츠, 레저</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=5" onclick="nhn.Kin.Utility.nClicks('LNB.kinlayer', '5', '11', event);" role="menuitem" tabindex="-1">쇼핑</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=13" onclick="nhn.Kin.Utility.nClicks('LNB.jun', '', '', event);" role="menuitem" tabindex="-1">쥬니버Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=12" onclick="nhn.Kin.Utility.nClicks('LNB.loc', '', '', event);" role="menuitem" tabindex="-1">지역&amp;플레이스</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/qna/list.naver?dirId=20" onclick="nhn.Kin.Utility.nClicks('LNB.talk', '', '', event);" role="menuitem" tabindex="-1">고민Q&amp;A</a></li>
# <li class="sub_menu" role="presentation"><a class="item" href="/opendic/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.open', '', '', event);" role="menuitem" tabindex="-1">오픈사전</a></li>
# </ul>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/qna/questionList.naver" onclick="nhn.Kin.Utility.nClicks('LNB.answer', '', '', event);" role="menuitem" tabindex="-1"><em>답변하기</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/volunteer/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.donation', '', '', event);" role="menuitem" tabindex="-1"><em>지식기부</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/people/elite/index.naver?from=lnb" id="peopleLnbBtn" onclick="nhn.Kin.Utility.nClicks('LNB.people', '', '', event);" role="menuitem" tabindex="-1"><em>사람들</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/best/listaha.naver" onclick="nhn.Kin.Utility.nClicks('LNB.best', '', '', event);" role="menuitem" tabindex="-1"><em>베스트</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/hall/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.honor', '', '', event);" role="menuitem" tabindex="-1"><em>명예의전당</em></a>
# </li>
# <li class="menu" role="presentation">
# <span class="lnb_bar">|</span>
# <a class="item" href="/myinfo/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.profile', '', '', event);" role="menuitem" tabindex="-1"><em>프로필</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/partnercenter/index.naver" onclick="nhn.Kin.Utility.nClicks('LNB.partner', '', '', event);" role="menuitem" tabindex="-1"><em>파트너센터</em></a>
# </li>
# <li class="menu" role="presentation">
# <a class="item" href="/roulette/home.naver" onclick="nhn.Kin.Utility.nClicks('LNB.roulette', '', '', event);" role="menuitem" tabindex="-1"><em>룰렛</em></a>
# </li>
# </ul>

# %%
ul=soup.find_all('ul',class_="ranking_list")
ul[1]
# Out:
# <ul class="ranking_list">
# <li class="ranking_item _item_4">
# <span class="no">4</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=4&amp;dirId=4020202&amp;docId=437125718" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">임대차법 질문</a>
# <a class="text" href="/qna/detail.naver?d1id=4&amp;dirId=4020202&amp;docId=437125718" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">예를들어서 제가 집을 매매했는데 그 집에 전주인이 1년월세로계약해서 살고있는 세입자가있는상황에서 세...</a>
# <span class="recommend_num">조회수 31</span><span class="reply_num">답변수 3</span>
# </li>
# <li class="ranking_item _item_5">
# <span class="no">5</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=8&amp;dirId=81302&amp;docId=437154274" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">편의점 택배 얼마나 걸릴까요</a>
# <a class="text" href="/qna/detail.naver?d1id=8&amp;dirId=81302&amp;docId=437154274" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">편의점 택배 받으려하는데 며칠동안 계속 멈춰있는데 이럴때는 어떻게 해야하나요 ??운송장 번호는 3643792...</a>
# <span class="recommend_num">조회수 27</span><span class="reply_num">답변수 1</span>
# </li>
# <li class="ranking_item _item_6">
# <span class="no">6</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=110503&amp;docId=437133793" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">유치원 정교사 자격증 2급</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=110503&amp;docId=437133793" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">아동보육과로 2년제 졸업 후 어린이집에 2년차 근무 중입니다. 유치원으로 근무를 희망해서 자격증을 따려...</a>
# <span class="recommend_num">조회수 26</span><span class="reply_num">답변수 19</span>
# </li>
# </ul>

# %%
divs=soup.find('div', class_="ranking_list_area")
lis=divs.find_all('li')
print(lis[0].get_text())
# Out:
# 1
# 대학교 순위 알려주세요
# 대학교 순위 알려주세요 수원대학교,계명대학교,용인대학교,성결대학교,협성대학교,강남대학교,안양대학교,...
# 조회수 46답변수 20

# %%
print(lis[0].find_all('span')[0].get_text()) # 순위 

print(lis[0].find_all('a')[0].get_text()) # 제목
print(lis[0].find_all('a')[1].get_text()) # 요약 내용

print(lis[0].find_all('span')[1].get_text())
print(lis[0].find_all('span')[2].get_text())
# Out:
# 1
# 대학교 순위 알려주세요
# 대학교 순위 알려주세요 수원대학교,계명대학교,용인대학교,성결대학교,협성대학교,강남대학교,안양대학교,...
# 조회수 46
# 답변수 20

# %% [markdown]
# #### 3. CSS Selector를 사용한 크롤링
# - select 함수 사용

# %%
import requests
from bs4 import BeautifulSoup as bs

url='https://kin.naver.com/'

res=requests.get(url)

# 데이터를 가져오지 못하면 메세지 출력후 강제 종료한다.
if res.status_code != 200:
    exit('데이터를 가져오기 못했습니다.')

soup = bs(res.content, 'html.parser')

# %%
# 태그를 이용한 검색이다.
soup.find('title')

# select 함수를 이용한 태그 검색이다. -> 결과는 !!!리스트!!! 형태로 반환해준다.
# select함수는 find_all()과 동일한 결과값 반환해준다.

soup.select('title')[0]
# Out:
# <title>
# 	네이버 지식iN
# </title>

# %%
soup.select('html title')[0] # soup.select('html head title')[0]
# Out:
# <title>
# 	네이버 지식iN
# </title>

# %%
lis=soup.select('div.ranking_list_area li')
lis[0]
# Out:
# <li class="ranking_item _item_1">
# <span class="no">1</span>
# <a class="ranking_title" href="/qna/detail.naver?d1id=11&amp;dirId=110408&amp;docId=437036038" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">대학교 순위 알려주세요</a>
# <a class="text" href="/qna/detail.naver?d1id=11&amp;dirId=110408&amp;docId=437036038" onclick="nhn.Kin.Utility.nClicks('hrk.list', '', '', event);" target="_blank">대학교 순위 알려주세요 수원대학교,계명대학교,용인대학교,성결대학교,협성대학교,강남대학교,안양대학교,...</a>
# <span class="recommend_num">조회수 46</span><span class="reply_num">답변수 22</span>
# </li>

# %%
print(lis[0].find_all('span')[0].get_text())
print(lis[0].find_all('a')[0].get_text())
print(lis[0].find_all('a')[1].get_text())
print(lis[0].find_all('span')[1].get_text())
print(lis[0].find_all('span')[2].get_text())
# Out:
# 1
# 대학교 순위 알려주세요
# 대학교 순위 알려주세요 수원대학교,계명대학교,용인대학교,성결대학교,협성대학교,강남대학교,안양대학교,...
# 조회수 46
# 답변수 22

# %%
# select를 쓰는 이유가 아래 출력처럼 클래스를 찾아줄 수 있다.
lis=soup.select('div.ranking_list_area li span.no')
lis[0].text
# Out:
# '1'

# %% [markdown]
# #### [정리] 네이버 지식인의 '많이 본 Q&A' 데이터 크롤링
# 1. 9개의 데이터 크롤링
# 2. 결과는 Pandas의 DataFrame으로 저장
# 3. columns: ['no','title', 'doct', 'view','answer']

# %%
import requests
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

url='https://kin.naver.com/'

html= requests.get(url) # 지식인에 내용 요청
if html.status_code != 200: # 데이터를 받았는지 확인
  exit() # 데이터가 정상이 아니면 프로그램 강제종료

# 가져온 데이터를 폅집하기 좋게 정보만 추출
soup = bs(html.content,'html.parser') 

# 정보가 있는 li 태그 모두 검색
lis=soup.select('div.ranking_list_area li') 
print(f'li 태그 갯수: {len(lis)}')

# 각 텍스트를 가져와 DataFrame으로 출력
df_list=[]

# 검색된 li 태그를 순차적으로 가져와 각각의 값 추출해준다.
for li in lis:
  no=li.find_all('span')[0].get_text() # 순위 값 추출
  title=li.find_all('a')[0].text # 제목 추출
  doct=li.find_all('a')[1].getText() # 요약내용 추출
  view=li.find_all('span')[1].text # 조회 건수 추출
  view=view.split(" ")[1]
  answer=li.find_all('span')[2].text # 답변 건수 추출
  answer=answer.split(" ")[1]

# df로 바꾸기 위해 df_list에 추가
  df_list.append({'no':no, 'title':title,'doct':doct,'view':view,'answer':answer})

df=pd.DataFrame(df_list)
df
# Out:
# li 태그 갯수: 9
#   no                 title                                               doct  \
# 0  1          대학교 순위 알려주세요  대학교 순위 알려주세요 수원대학교,계명대학교,용인대학교,성결대학교,협성대학교,강남대...
# 1  2  과학자와 수학자의 차이는 무엇인가요?                               과학자와 수학자의 차이는 무엇인가요?
# 2  3   (중딩)리만가설이 무엇인가요?? 말        (중딩)리만가설이 무엇인가요?? 말 그자체로 소수인가요??? 모르겠어요ㅠㅠ..
# 3  7          6명의 키를 구해주세요  키가 큰 순서는 민찬>민하>나은>채은>호영>소이 이며, 여섯명의 평균키는 151.5...
# 4  8               지구과학 문제  ㄴ에서 북서쪽으로 간다는데 제 긂으로 보면 부샤 동남 두쪽으로가는거아닌가요? 어ㅐ ...
# 5  9           대학 유급 국가장학금  혹시 1학년 2학기를 유급하면 국가장학금은 1학년 1학기 성적으로 2학기를 다시 다...
# 6  4               임대차법 질문  예를들어서 제가 집을 매매했는데 그 집에 전주인이 1년월세로계약해서 살고있는 세입자...
# 7  5       편의점 택배 얼마나 걸릴까요  편의점 택배 받으려하는데 며칠동안 계속 멈춰있는데 이럴때는 어떻게 해야하나요 ??운...
# 8  6        유치원 정교사 자격증 2급  아동보육과로 2년제 졸업 후 어린이집에 2년차 근무 중입니다. 유치원으로 근무를 희...
#
#   view answer
# 0   46     23
# 1   40      1
# 2   39      3
# 3   26      1
# 4   24      1
# 5   21      1
# 6   31      3
# 7   27      1
# 8   26     20

# %% [markdown]
# #### [미션] 네이버 지식인에서 '부산 서면 맛집' 검색후 크롤링
# - 크롤링 항목: 등록일, 제목, 요약내용, 답변수, 추천수
# - 결과는 DataFrame로 출력

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
# url 생성
sch=input('검색어 입력:')
url='https://kin.naver.com/search/list.naver?query=' + sch

#https://kin.naver.com/search/list.naver?query=검색어&page=2

# 정보 요청
html = requests.get(url)
if html.status_code != 200:exit()  # 정보 오류 여부 확인

# 정부 추출
soup = bs(html.text, 'html.parser') 
lis = soup.select('ul.basic1 li')

# 추출한 정보를 이용해 DF 생성
df_list = []

for li in lis:
    dt = li.select('dd.txt_inline')[0].text    # 입력일
    title = li.select('a')[0].text   # 제목
    doct = li.select('dd')[1].text   # 내용 요약
    ans = li.select('span.hit')[0].text.replace('답변수 ',"") # 답변수
    
    # 추천수
    tmp = li.select('dd.txt_block')[0].text
    tmp = tmp.replace('\n',"").replace('\t',"").split()
    rec = tmp[tmp.index('추천수')+1].replace('|답변',"")
    df_list.append({'indate':dt,
                    'title':title,
                    'doct':doct,
                    'answer':ans,
                    'recommend':rec})
    
df=pd.DataFrame(df_list)
df
# Out:
# 검색어 입력:서면 맛집
#         indate               title  \
# 0  2023.01.06.
# 1  2022.01.27.
# 2  2022.11.15.   서면 맛집 고기집 추천해주세요!
# 3  2022.12.25.       서면 맛집이 궁금합니다.
# 4  2022.03.23.
# 5  2022.08.29.   서면 맛집 고기집 추천해주세요!
# 6  2022.05.10.            부산 서면 맛집
# 7  2022.12.20.  부산 서면/광안리 맛집 알려주세요
# 8  2022.06.21.            부산 서면 맛집
# 9  2022.09.23.   서면 놀거리 맛집 추천 해주세요
#
#                                                 doct answer recommend
# 0  ... 그런걸로 지역이 나뉜다는데 어느쪽에 서면맛집이 많은가요? 그것도 궁금해요~!...      1         4
# 1  부산 서면 맛집 분위기 좋은 곳 알려주세요. 곧 다가오는 기념일에 여자친구랑 데이트...      1         3
# 2  서면 맛집 중에 고기집있나요! 고기가 먹고 싶어서 ㅋㅋ 서면 맛집 중에 맛있는 고깃...      1         0
# 3  먹었을때 가격대비 후회없는 맛집 위치와 맛있게 먹었던 메뉴+가격 알려주시면 감사해요...      1         0
# 4  ... #부산서면맛집 #서면수제버거 #서면로위버거 #수제버거맛집 #로위버거 *광고 ...      1         0
# 5  안녕하세여 서면 맛집 중에 고기집있나요! 고기가 먹고 싶어서 ㅋㅋ 서면 맛집 중에 ...      2         0
# 6  부산 서면 맛집 추천해주세요 저녁 먹고 술집으로 갈꺼라서 거하게는 못 먹을듯해요~ ...      6         0
# 7  부산 서면 친구들7명 정도 놀러 갈 건데 인스타 피드 채울 싸고 맛있는 맛집 추천 ...      2         0
# 8  안녕하세요 이번 주말에 서면에 가기로 했는데 맛집 추천좀 해주세요 1인분 당 가격이...      3         0
# 9  친구랑 오늘 서면에서 놀기로 했는데 서면 맛집 추천해주세요 막 엄청 흔하고 그런 곳...      3         0

# %%
tmp
# Out:
# ['지역&플레이스', '>', '서면|답변수', '3', '추천수', '0']

# %% [markdown]
# #### url 추출 및 내부 정보 크롤링

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# url 생성
sch=input('검색어 입력:')
page=1
url='https://kin.naver.com/search/list.naver?query=' + sch + "&page=" + str(page)

# 정보 요청
html = requests.get(url)
if html.status_code != 200:exit()  # 정보 오류 여부 확인

# 정보 추출
soup = bs(html.text, 'html.parser') 
lis = soup.select('ul.basic1 li')

# 추출한 정보를 이용해 DF 생성
df_list = []

for li in lis:
    dt = li.select('dd.txt_inline')[0].text    # 입력일
    acnt = li.select('span.hit')[0].text.replace('답변수 ',"") # 답변수
    links=li.find('a')['href']

    df_list.append({'indate':dt,
                    'answer_cnt':acnt,
                    'lints':links})
    
df=pd.DataFrame(df_list)
df
# Out:
# 검색어 입력:부산 서면 맛집
#         indate answer_cnt                                              lints
# 0  2022.01.27.          1  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 1  2022.12.26.          1  https://kin.naver.com/qna/detail.naver?d1id=12...
# 2  2022.03.23.          1  https://kin.naver.com/qna/detail.naver?d1id=12...
# 3  2022.12.20.          2  https://kin.naver.com/qna/detail.naver?d1id=12...
# 4  2022.05.10.          6  https://kin.naver.com/qna/detail.naver?d1id=12...
# 5  2022.06.21.          3  https://kin.naver.com/qna/detail.naver?d1id=12...
# 6  2022.07.04.          2  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 7  2023.01.02.          1  https://kin.naver.com/qna/detail.naver?d1id=12...
# 8  2023.01.06.          1  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 9  2022.12.05.          2  https://kin.naver.com/qna/detail.naver?d1id=8&...

# %% [markdown]
# #### 답변 데이터 가져오기

# %%
df_list=[]
for link in df['lints']:
    # 정보 요청
    html = requests.get(link)
    if html.status_code != 200: # 정보 오류 여부 확인
        continue
    
    # 정보 추출
    soup = bs(html.text, 'html.parser') 
    anscnt=soup.find('em', class_="_answerCount num").text

    if int(anscnt) < 1:
      continue
    #print(anscnt)

    # 답변 텍스트 추출
    divs=soup.select('div.answer-content div.se-main-container')
    #print(len(divs))

    # 데이터 추가
    for div in divs:
      df_list.append({'검색어':sch,
                      '답변내용':div.text})
df=pd.DataFrame(df_list)
df
# Out:
#          검색어                                               답변내용
# 0   부산 서면 맛집       서면은 워낙 번화가다 보니까 확실히 저도 맛집을 찾는게 어렵긴 하더라구요저...
# 1   부산 서면 맛집       부산 서면 보신탕맛집답변드릴게요!서면집이라고 하는 영양탕 집이 있는데​부산...
# 2   부산 서면 맛집       안녕하세요:) 플래너 다다입니다.삼보게임랜드 근처 맛집을 찾으시군요~학생이...
# 3   부산 서면 맛집                 싸고 맛있는은 모르겠지만..기장 우대갈비집 맛있었어요
# 4   부산 서면 맛집       친구들끼리 부산 놀러가시는군요!​부산에는 워낙 맛집들이 많아 일일히 다 말...
# 5   부산 서면 맛집                     애주당서면 골목오뎅빠술고당취향인지 검색해보세요
# 6   부산 서면 맛집       제 아이디 들어가셔서 프로필 바로 오른쪽에 보시면 야식코너 있는데제 블로그...
# 7   부산 서면 맛집       안녕하세요 맛집을 알아보시는 것 같은데요맛집 알아보실 때 네이버 검색창에서...
# 8   부산 서면 맛집       서면은 술집이죠.그 다음 해장할수있는 집.제가 자주가는 코스는 1차는 해물...
# 9   부산 서면 맛집       ~~ 서면 아래 추천합니다 간단하게 칼국수 간단하게 먹고 가세요 ~~고요스...
# 10  부산 서면 맛집       제 개인적인 생각으로 써봅니다. 다 서면 근방입니다​1. 양정 어랑대구왕뽈...
# 11  부산 서면 맛집       http://naver.me/xM28zZzK              정을담...
# 12  부산 서면 맛집       부산맛도리집으로다가 저장해놨습니다.​찐맛도리집공유 내돈내산여행공유https...
# 13  부산 서면 맛집       저는 서면 살아서 친구들이랑 일주일에 한번은 꼭!! 방문하는곳이에요!'분짜...
# 14  부산 서면 맛집       부산 맛집 다양한 곳이 있죠~색다르게 먹어보는 것도 좋을 것 같아요 ㅎㅎ부...
# 15  부산 서면 맛집       안녕하세요 질문에 대한 답변 드리겠습니다.​가성비와 분위기 둘 다 좋은 “...
# 16  부산 서면 맛집       질문자님 너무 귀엽네요.zz저도 부산에 거주한지 꽤 오래 되었는데요.​첫번...
# 17  부산 서면 맛집       제가 자주 방문하는 소인수분해 방문해 보세요 후회 없으실 겁니다​소인수분해...
# 18  부산 서면 맛집       인공곱 넣는 경우가 많기 때문에곱이 많다 해서 마냥 좋은 건 아닌듯 합니다...

# %% [markdown]
# ####[미션] 여러 page 데이터 가져오기
# - 사용자로부터 검색어, 페이지 입력
# - 검색어/답변 => DataFrame로 출력
