# %% [markdown]
# #### Numpy(넘파이) 특징
# - 과학 계산을 위한 라이브러리(모듈)
# - 행렬/배열 처리 및 연산

# %%
import numpy as np

tmp=[1,2,3,4,5,6]
arr=np.array(tmp)
print(tmp, "\n", arr)
print(type(tmp))
print(type(arr))
# Out:
# [1, 2, 3, 4, 5, 6]
#  [1 2 3 4 5 6]
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
tmp=[1, 2, 3, '사', 5, 6]
arr=np.array(tmp)
print(tmp, "\n", arr)
# Out:
# [1, 2, 3, '사', 5, 6]
#  ['1' '2' '3' '사' '5' '6']
