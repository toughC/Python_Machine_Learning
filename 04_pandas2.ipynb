# %% [markdown]
# ##### 한글 폰트 설치

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %% [markdown]
# ##### 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/dirve')
# Out:
# Mounted at /content/dirve

# %%
import pandas as pd
import numpy as np

dataDir='/content/dirve/MyDrive/Notability/Github/Python_Machine_Learning/data/'

# %%
df1=pd.read_excel(dataDir+"남북한발전전력량.xlsx")
df1
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
df1=pd.read_json(dataDir+"read_json_sample.json")
df1
# Out:
#            name  year        developer opensource
# pandas           2008    Wes Mckinneye       True
# NumPy            2006  Travis Oliphant       True
# matplotlib       2003   John D. Hunter       True

# %%
df1=pd.read_csv(dataDir+'auto-mpg.csv', header=None)
df1
# Out:
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df1=pd.read_csv(dataDir+'df_sample.csv', header=1)
df1
# Out:
#   Jerry   A   C  B+
# 0  Riah  A+   B   C
# 1  Paul   B  B+  C+

# %%
import pandas as pd
dataDir2='/content/dirve/MyDrive/Notability/Github/Python_Machine_Learning/'
df=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소).xls', header=2)
df.head()  # 상위 5개(기본값) 출력
# Out:
#       지역               상호                         주소      상표          전화번호  \
# 0  부산광역시           신항만주유소       부산 강서구 가락대로1243번길 68  현대오일뱅크  051-973-0935
# 1  부산광역시            이왕주유소  부산 강서구 대저로255번길 21 (대저1동)  현대오일뱅크  051-972-9007
# 2  부산광역시  (주)만은에너지 대사리주유소       부산 강서구 낙동북로 65 (강동동)   GS칼텍스  051-973-5999
# 3  부산광역시  지에스칼텍스㈜ 동성셀프주유소          부산 강서구 명지국제8로 272   GS칼텍스  051-292-0895
# 4  부산광역시  (주)우양네트웍스 송산주유소       부산 강서구 호계로 200 (죽동동)   S-OIL  051-973-7583
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    Y     -  1459  1639     -
# 1    Y     -  1478  1678  1400
# 2    Y     -  1478  1638     -
# 3    Y     -  1479  1619     -
# 4    Y     -  1485  1645     -

# %%
df.tail(3)   # 하위 5개(기본) 출력
# Out:
#        지역                상호                       주소     상표           전화번호  \
# 48  부산광역시        녹산화물터미널주유소  부산 강서구 녹산산업북로 119 (송정동)  GS칼텍스   051-941-3015
# 49  부산광역시  내트럭(주) 부산신항남컨사업소          부산 강서구 신항남로 507  SK에너지  070-4454-9235
# 50  부산광역시   광신석유(주)직영 명지주유소  부산 강서구 르노삼성대로 372 (명지동)  SK에너지   051-271-4405
#
#    셀프여부 고급휘발유   휘발유    경유  실내등유
# 48    N     -  1595  1695     -
# 49    N     -  1668  1729     -
# 50    Y  1999  1799  1899  1799

# %%
# 정보확인
df.info
# Out:
# <bound method DataFrame.info of        지역                   상호                         주소      상표  \
# 0   부산광역시               신항만주유소       부산 강서구 가락대로1243번길 68  현대오일뱅크
# 1   부산광역시                이왕주유소  부산 강서구 대저로255번길 21 (대저1동)  현대오일뱅크
# 2   부산광역시      (주)만은에너지 대사리주유소       부산 강서구 낙동북로 65 (강동동)   GS칼텍스
# 3   부산광역시      지에스칼텍스㈜ 동성셀프주유소          부산 강서구 명지국제8로 272   GS칼텍스
# 4   부산광역시      (주)우양네트웍스 송산주유소       부산 강서구 호계로 200 (죽동동)   S-OIL
# 5   부산광역시          은마석유 경기장주유소     부산 강서구 낙동북로 364 (대저1동)   GS칼텍스
# 6   부산광역시               우리2주유소      부산 강서구 낙동북로 142 (강동동)   알뜰주유소
# 7   부산광역시        세기상사(주) 공항주유소      부산 강서구 공항로 469 (대저2동)   S-OIL
# 8   부산광역시      은마석유(주)직영 강서주유소             부산 강서구 공항로 483  현대오일뱅크
# 9   부산광역시        CJ대한통운㈜ 성민주유소      부산 강서구 가락대로 389 (송정동)   S-OIL
# 10  부산광역시            (주)젤코바에너지            부산 강서구 낙동남로 700   S-OIL
# 11  부산광역시        (주)시큐 국제산단주유소             부산 강서구 생곡로 272   GS칼텍스
# 12  부산광역시     (주)DJS신항만물류단지주유소      부산 강서구 가락대로 834 (범방동)   S-OIL
# ...

# %%
# 행/열의 갯수
df.shape
# Out:
# (51, 10)

# %%
# 데이터 타입
print(df.dtypes) #전체
print(df['경유'].dtypes)
#df.경유.types -> 경유가 영어라면 이렇게 쓸 수도 있음
# Out:
# 지역       object
# 상호       object
# 주소       object
# 상표       object
# 전화번호     object
# 셀프여부     object
# 고급휘발유    object
# 휘발유       int64
# 경유        int64
# 실내등유     object
# dtype: object
# int64

# %% [markdown]
# ##### 두개 이상의 파일 하나로 만들기(행추가)

# %%
df1=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (1).xls', header=2)
df2=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (2).xls', header=2)

display(df1.head(3))
display(df2.head(3))
# Out:
#       지역                  상호                      주소      상표          전화번호  \
# 0  부산광역시      지에스칼텍스(주)신창주유소  부산 금정구 중앙대로 1698 (부곡동)   GS칼텍스  051-581-1212
# 1  부산광역시  현대오일뱅크㈜ 직영 금정셀프주유소  부산 금정구 중앙대로 1664 (부곡동)  현대오일뱅크  051-583-8951
# 2  부산광역시          은마석유 노포주유소  부산 금정구 중앙대로 2191 (노포동)   GS칼텍스  051-508-1645
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    Y  1704  1489  1699  1600
# 1    Y     -  1489  1699     -
# 2    Y     -  1494  1634  1500
#       지역             상호                  주소      상표          전화번호 셀프여부 고급휘발유  \
# 0  부산광역시  은마석유(주) 대영주유소  부산 기장군 정관면 정관로 249   GS칼텍스  051-728-5133    Y     -
# 1  부산광역시       공단신도시주유소  부산 기장군 정관면 정관로 835  현대오일뱅크  051-728-4686    Y     -
# 2  부산광역시         백운1주유소  부산 기장군 정관면 정관로 779   GS칼텍스  051-728-4433    Y     -
#
#     휘발유    경유  실내등유
# 0  1465  1645     -
# 1  1475  1639  1550
# 2  1478  1639  1500

# %%
# 병합할 대상의 columns 확인
print(df1.columns)
print(df2.columns)
# Out:
# Index(['지역', '상호', '주소', '상표', '전화번호', '셀프여부', '고급휘발유', '휘발유', '경유', '실내등유'], dtype='object')
# Index(['지역', '상호', '주소', '상표', '전화번호', '셀프여부', '고급휘발유', '휘발유', '경유', '실내등유'], dtype='object')

# %%
# concat을 이용한 행 추가
df0=pd.concat([df1, df2], ignore_index=True)  # axis=0, ignore_index=True(병합후 인덱스 다시 부여)
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      66 non-null     object
#  1   상호      66 non-null     object
#  2   주소      66 non-null     object
#  3   상표      66 non-null     object
#  4   전화번호    66 non-null     object
#  5   셀프여부    66 non-null     object
#  6   고급휘발유   66 non-null     object
#  7   휘발유     66 non-null     int64
#  8   경유      66 non-null     int64
#  9   실내등유    66 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 5.3+ KB

# %% [markdown]
# ##### 부산 오피넷 주유 정보 병합하기

# %%
# 병합하기1
df1=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소).xls', header=2)
df2=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (1).xls', header=2)
df3=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (2).xls', header=2)
df4=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (3).xls', header=2)
df5=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (4).xls', header=2)
df6=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (5).xls', header=2)
df7=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (6).xls', header=2)
df8=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (7).xls', header=2)
df9=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (8).xls', header=2)
df10=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (9).xls', header=2)
df11=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (10).xls', header=2)
df12=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (11).xls', header=2)
df13=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (12).xls', header=2)
df14=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (13).xls', header=2)
df15=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (14).xls', header=2)
df16=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (15).xls', header=2)

df0=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15], 
              ignore_index=True)  # axis=0, ignore_index=True(병합후 인덱스 다시 부여)
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      339 non-null    object
#  1   상호      339 non-null    object
#  2   주소      339 non-null    object
#  3   상표      339 non-null    object
#  4   전화번호    339 non-null    object
#  5   셀프여부    339 non-null    object
#  6   고급휘발유   339 non-null    object
#  7   휘발유     339 non-null    object
#  8   경유      339 non-null    int64
#  9   실내등유    339 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 26.6+ KB

# %%
# 변수(객체) 삭제
del df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15

# %%
df0.loc[10]
# Out:
# 지역                 부산광역시
# 상호             (주)젤코바에너지
# 주소       부산 강서구 낙동남로 700
# 상표                 S-OIL
# 전화번호        051-832-7560
# 셀프여부                   N
# 고급휘발유                  -
# 휘발유                 1489
# 경유                  1625
# 실내등유                   -
# Name: 10, dtype: object

# %%
# os 모듈 이용
import os
import glob

#fnames=glob.glob(dataDir+'oildata/*.xls')
#fnames
fnames=os.listdir(dataDir2+'oilData/')
fnames

#for i in range(1,16):
#  df=pd.read_excel(dataDir2+'oilData/지역_위치별(주유소) (%d).xls'%i, header=2)
#  #display(df.head(3))
#  df0=pd.concat([df0, df], ignore_index=True)

#df0
# Out:
# ['지역_위치별(주유소).xls',
#  '지역_위치별(주유소) (1).xls',
#  '지역_위치별(주유소) (2).xls',
#  '지역_위치별(주유소) (3).xls',
#  '지역_위치별(주유소) (4).xls',
#  '지역_위치별(주유소) (5).xls',
#  '지역_위치별(주유소) (6).xls',
#  '지역_위치별(주유소) (7).xls',
#  '지역_위치별(주유소) (8).xls',
#  '지역_위치별(주유소) (9).xls',
#  '지역_위치별(주유소) (10).xls',
#  '지역_위치별(주유소) (11).xls',
#  '지역_위치별(주유소) (12).xls',
#  '지역_위치별(주유소) (13).xls',
#  '지역_위치별(주유소) (14).xls',
#  '지역_위치별(주유소) (15).xls']

# %%
#### 병합하기
df0=pd.DataFrame()   # 누적 DF생성

for fn in fnames:
    df1 = pd.read_excel(dataDir2+'oilData/'+fn, header=2)
    #display(df1.head(1))
    df0=pd.concat([df0, df1], axis=0, ignore_index=True)

del df1
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      372 non-null    object
#  1   상호      372 non-null    object
#  2   주소      372 non-null    object
#  3   상표      372 non-null    object
#  4   전화번호    372 non-null    object
#  5   셀프여부    372 non-null    object
#  6   고급휘발유   372 non-null    object
#  7   휘발유     372 non-null    object
#  8   경유      372 non-null    int64
#  9   실내등유    372 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 29.2+ KB

# %% [markdown]
# ##### 데이터 살펴보기(3장)
# ### 문자형태를 INT형으로 전환하기

# %%
# 휘발유 타입 변경: df.astype({'대상필드':데이터형})
## df0=df0.astype({'휘발유':int})  # "-" 포함으로 에러 발생
df0.dtypes
# Out:
# 지역       object
# 상호       object
# 주소       object
# 상표       object
# 전화번호     object
# 셀프여부     object
# 고급휘발유    object
# 휘발유       int64
# 경유        int64
# 실내등유     object
# dtype: object

# %% [markdown]
# - 원하는 데이터 검색

# %%
df0[df0['휘발유']=="-"]

# %%
# 휘발유 필드에서 "-"가 포함된 데이터 삭제
# df0=df0.drop(90, axis=0) # 소량일 때 삭제법
df0=df0[df0['휘발유'] != "-"]  # 다량일 때 삭제법

# %%
# 휘발유 타입 변경: df.astype({'대상필드':데이터형})
df0=df0.astype({'휘발유':int})  # "-" 포함으로 에러 발생
df0.dtypes
df0
# Out:
#         지역                 상호                         주소      상표  \
# 0    부산광역시             신항만주유소       부산 강서구 가락대로1243번길 68  현대오일뱅크
# 1    부산광역시              이왕주유소  부산 강서구 대저로255번길 21 (대저1동)  현대오일뱅크
# 2    부산광역시    (주)만은에너지 대사리주유소       부산 강서구 낙동북로 65 (강동동)   GS칼텍스
# 3    부산광역시    지에스칼텍스㈜ 동성셀프주유소          부산 강서구 명지국제8로 272   GS칼텍스
# 4    부산광역시    (주)우양네트웍스 송산주유소       부산 강서구 호계로 200 (죽동동)   S-OIL
# ..     ...                ...                        ...     ...
# 367  부산광역시    SK에너지(주) 마리나주유소      부산 해운대구 해운대로 345 (우동)   SK에너지
# 368  부산광역시      ㈜은성석유 반송제일주유소      부산 해운대구 반송로 780 (석대동)   S-OIL
# 369  부산광역시  지에스칼텍스(주)해운대중동주유소        부산 해운대구 좌동로 34 (중동)   GS칼텍스
# 370  부산광역시    SK에너지(주) 돌고래주유소       부산 해운대구 해운대로573번길 16   SK에너지
# 371  부산광역시    에스씨(주) 마리나타운주유소     부산 해운대구 해운대해변로 44 (우동)   GS칼텍스
#
#              전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    051-973-0935    Y     -  1459  1639     -
# 1    051-972-9007    Y     -  1478  1678  1400
# ...

# %%
# 기본 데이터 저장하기
df0.to_csv(dataDir2+"20230104_oil.csv", encoding='cp949', index=False)

# %%
# 필요한 필드만 추출해 DataFrame 만들기(df1)
df1=df0[['상표', '상호', '주소', '셀프여부', '휘발유', '경유']]
df1.head(3)
# Out:
#        상표               상호                         주소 셀프여부   휘발유    경유
# 0  현대오일뱅크           신항만주유소       부산 강서구 가락대로1243번길 68    Y  1459  1639
# 1  현대오일뱅크            이왕주유소  부산 강서구 대저로255번길 21 (대저1동)    Y  1478  1678
# 2   GS칼텍스  (주)만은에너지 대사리주유소       부산 강서구 낙동북로 65 (강동동)    Y  1478  1638

# %%
# 데이터프레임 df0의 기술통계 정보 확인 
df1.describe()
# Out:
#                휘발유           경유
# count   371.000000   371.000000
# mean   1529.824798  1684.795148
# std      70.443721    68.263251
# min    1429.000000  1538.000000
# 25%    1495.000000  1645.000000
# 50%    1518.000000  1678.000000
# 75%    1548.000000  1699.000000
# max    1999.000000  2099.000000

# %%
df1.describe(include='all')
# Out:
#            상표     상호                   주소 셀프여부          휘발유           경유
# count     371    371                  371  371   371.000000   371.000000
# unique      7    369                  370    2          NaN          NaN
# top     SK에너지  대일주유소  부산 기장군 정관면 신정관로 188    Y          NaN          NaN
# freq      111      2                    2  270          NaN          NaN
# mean      NaN    NaN                  NaN  NaN  1529.824798  1684.795148
# std       NaN    NaN                  NaN  NaN    70.443721    68.263251
# min       NaN    NaN                  NaN  NaN  1429.000000  1538.000000
# 25%       NaN    NaN                  NaN  NaN  1495.000000  1645.000000
# 50%       NaN    NaN                  NaN  NaN  1518.000000  1678.000000
# 75%       NaN    NaN                  NaN  NaN  1548.000000  1699.000000
# max       NaN    NaN                  NaN  NaN  1999.000000  2099.000000

# %% [markdown]
# ### 데이터 계산

# %% [markdown]
# - 데이터 개수

# %%
print(f'전체데이터: {len(df1)}\n')
df1.count()
# Out:
# 전체데이터: 371
# 상표      371
# 상호      371
# 주소      371
# 셀프여부    371
# 휘발유     371
# 경유      371
# dtype: int64

# %%
df1.count()['상표']  # 시리즈 객체로 각 필드의 값을 사용할 수 있음
# Out:
# 371

# %%
# 데이터프레임에서 특정 열이 가지고 있는 고유값 확인
unique_val=df1['셀프여부'].value_counts()
unique_val
# Out:
# Y    270
# N    101
# Name: 셀프여부, dtype: int64

# %% [markdown]
# - 평균값

# %%
# 특정 필드의 평균 계산
df1['휘발유'].mean()
# Out:
# 1529.8247978436657

# %%
# 전체 데이터의 평균 계산/숫자 데이터에 대한 필드만 계산
df1.mean()
# Out:
# <ipython-input-76-a17dca8d29d9>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# 휘발유    1529.824798
# 경유     1684.795148
# dtype: float64

# %%
# 특정 필드의 평균 계산
df1[['휘발유', '경유']].mean()
# Out:
# 휘발유    1529.824798
# 경유     1684.795148
# dtype: float64

# %%
type(df1[['휘발유', '상표']].mean())  # 문자필드의 경우 계산에서 자동 생략
# Out:
# <ipython-input-78-c90255de434b>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   type(df1[['휘발유', '상표']].mean())  # 문자필드의 경우 계산에서 자동 생략
# pandas.core.series.Series

# %% [markdown]
# - 중앙값

# %%
df.median()
# Out:
# <ipython-input-79-6d467abf240d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# 휘발유    1499.0
# 경유     1649.0
# dtype: float64

# %%
df1['휘발유'].median()
# Out:
# 1518.0

# %% [markdown]
# - 최대값/최값

# %%
df1.max()
# Out:
# 상표                            현대오일뱅크
# 상호                        흥일주유소 주식회사
# 주소      부산광역시 해운대구  수영강변대로 504 (반여동)
# 셀프여부                               Y
# 휘발유                             1999
# 경유                              2099
# dtype: object

# %%
df1['경유'].max()
# Out:
# 2099

# %%
df1.max()
# Out:
# 상표                            현대오일뱅크
# 상호                        흥일주유소 주식회사
# 주소      부산광역시 해운대구  수영강변대로 504 (반여동)
# 셀프여부                               Y
# 휘발유                             1999
# 경유                              2099
# dtype: object

# %%
df1['경유'].min()
# Out:
# 1538

# %% [markdown]
# - 표준편차

# %%
df1.std()
# Out:
# <ipython-input-85-1c22e8bf5753>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# 휘발유    70.443721
# 경유     68.263251
# dtype: float64

# %%
df1['경유'].std()
# Out:
# 68.26325099097127

# %% [markdown]
# - 상관계수

# %%
df1.corr()
# Out:
#           휘발유        경유
# 휘발유  1.000000  0.779656
# 경유   0.779656  1.000000

# %% [markdown]
# #### 시각화
# - matplotlib

# %%
df2=df1[df1['상표']=='현대오일뱅크']
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 0 to 356
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   상표      72 non-null     object
#  1   상호      72 non-null     object
#  2   주소      72 non-null     object
#  3   셀프여부    72 non-null     object
#  4   휘발유     72 non-null     int64
#  5   경유      72 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 3.9+ KB

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

df2[['휘발유', '경유']].plot()

plt.show()

# %%
df2[['휘발유', '경유']].plot(kind='bar', figsize=(12,5))
plt.show()

# %%
df2[['휘발유', '경유']].plot(kind='barh', figsize=(5,10))
plt.show()

# %%
df2[['휘발유', '경유']].plot(kind='hist')
plt.show()

# %%
df.plot(x='셀프여부', y='상표', kind='scatter')
plt.show()

# %%
df2[['휘발유', '경유']].plot(kind='box')
plt.show()
